# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import math
import matplotlib.pyplot as plt

# %%
x = [x for x in range(-25, 26)]
y = [x[i]**2 for i in range(len(x))]
plt.plot(x,y)
points = list(map(list,zip(x,y)))
points = np.array(points)

# %%
np.savetxt('test_points.txt', points, delimiter=', ')
