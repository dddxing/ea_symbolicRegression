# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import copy
import math
import tqdm
from datetime import datetime
from sklearn.model_selection import train_test_split
import traceback

# %%
filename = "test_points"
df = pd.read_csv(f'{filename}.txt', header = None, sep=", ", names=["x", 'y'], engine='python')
operators1 = ['+', '-', '*', '/', 'sin', 'cos', 'const', 'x']
operators2 = ['const', 'x']

num_evaluation = 5000
depth = 4

x_s = df["x"].to_numpy()
y_s = df["y"].to_numpy()
y_s = [float(y) for y in y_s]

df.head()
# Out:
#       x      y
# 0 -25.0  625.0
# 1 -24.0  576.0
# 2 -23.0  529.0
# 3 -22.0  484.0
# 4 -21.0  441.0

# %%
plt.plot(x_s, y_s);

# %%
def find_all_children(arr):
    """
    random pick a parent node and return it in a list with ALL its children (children, grand-children)  
    """
    
    res = []
    ptr = 0
    n = random.randint(2*len(arr)//5, len(arr)//2) # len(arr)-1
    res.append(n)
    
    while res[ptr] <= len(arr)-1:
        if 2 * res[ptr] <= len(arr)-1:
            res.append(2*res[ptr])
        else: break
        if 2 * res[ptr] + 1 <= len(arr)-1:
            res.append(2*res[ptr]+1)
        else: break
            
        ptr += 1
    return res


def merge(dict1, dict2):
    """merge two dictionaries"""
    res = {**dict1, **dict2}
    return res

# %%
def random_generate(depth):
    """
    generate a sequence of binary heap
    INPUTS:
        depth: depth of the binary tree -> int
    
    OUTPUT:
        binary heap
    """
    
    max_length = 2 ** depth - 1
    
    length = random.randint(1, max_length)
    first_half = length//2
    second_half = length - first_half
    
    res = ['nah']
    
    for i in range(1, first_half):
        pick = random.choice(operators1)
        
        if (pick == res[i-1]) and (res[i//2] == '-'):
            tmp = copy.deepcopy(operators1)
            tmp.remove(res[i-1])
            pick = random.choice(tmp)
            
        if pick == "const":
            pick = round(random.random() * 10 + 0.1, 4)
            
        res.append(pick)
        
    for i in range(first_half, length):
        
        pick = random.choices(population=operators2, weights=(0.5, 0.5))[0]
        
        if (pick == res[i-1]) and (res[i//2] == '-'):
            tmp = copy.deepcopy(operators2)
            tmp.remove(res[i-1])
            pick = random.choice(tmp)
            
        if pick == "const":
            pick = round(random.random() * 10 + 0.1, 4)
            
        res.append(pick)
        
    return res

# %%
random_generate(depth=5)
# Out:
# ['nah',
#  'sin',
#  9.2717,
#  '*',
#  '+',
#  '*',
#  'cos',
#  'cos',
#  'x',
#  'x',
#  'x',
#  'x',
#  6.4934,
#  7.236,
#  9.1758,
#  9.0874,
#  'x',
#  7.095,
#  'x']

# %%
def mutate(binary_heap, mutate_rate):
    
    binaryheap = copy.deepcopy(binary_heap)
    
    ele = int(len(binaryheap) * mutate_rate)
    
    for i in range(ele):
        ptr = random.randint(1, len(binaryheap)-1)

        if ptr < len(binaryheap)//2:
            pick = random.choice(operators1)

            if (pick == binaryheap[ptr-1]) and (binaryheap[ptr//2] == '-'):
                tmp = copy.deepcopy(operators1)
                tmp.remove(binaryheap[ptr-1])
                pick = random.choice(tmp)       

        else:
            pick = random.choice(operators2)

            if (pick == binaryheap[ptr-1]) and (binaryheap[ptr//2] == '-'):
                tmp = copy.deepcopy(operators2)
                tmp.remove(binaryheap[ptr-1])
                pick = random.choice(tmp)

        if pick == "const":
            pick = round(random.random() * 10 + 0.1, 4)
        
        binaryheap[ptr] = pick

    return binaryheap

# %%
a = random_generate(depth=4)
a
# Out:
# ['nah', 'sin', 3.5084, 7.5299]

# %%
mutate(a, 0.5)
# Out:
# ['nah', 'sin', 7.0466, 'x']

# %%
def evaluate_binary_heap(binary_heap, x):
    
    """
    Evaluate binary from back to front
    
    """
    
    bh = copy.deepcopy(binary_heap)
    for i in range(len(bh)-1, 0, -1):
        try:
            if bh[i] == 'x':
                bh[i] = x

            elif bh[i] == '+':

                bh[i] = bh[2*i] + bh[2*i+1]

            elif bh[i] == '-':

                bh[i] = bh[2*i] - bh[2*i+1]

            elif bh[i] == '*':

                bh[i] = bh[2*i] * bh[2*i+1]

            elif bh[i] == '/':

                bh[i] = bh[2*i] / bh[2*i+1]

            elif bh[i] == 'sin':

                bh[i] = np.sin(bh[2*i])

            elif bh[i] == 'cos':

                bh[i] = np.cos(bh[2*i])
        except:
#             return random.random()
            return 10
#             pass
#             print(f"Math invalid")
#             print(binary_heap)
            
    return bh[1]

# %%
def calculate_y(x_s, equation):
    calculated_y = []
    for ele in x_s:
        res = evaluate_binary_heap(equation, x=ele)
        calculated_y.append(res)
    return calculated_y

# %%
a = random_generate(depth=4)
b = random_generate(depth=4)
print(f"a = {a}")
print(f"b = {b}")

print(f"evaluate a: {evaluate_binary_heap(a, x=2)}")
print(f"evaluate a: {evaluate_binary_heap(b, x=2)}")
crossover(a,b)
# Out:
# a = ['nah', '-', 'x', 1.8844, 'x', 'x', 'x']
# b = ['nah', 6.2675]
# evaluate a: 0.11559999999999993
# evaluate a: 6.2675
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-532fb330e730> in <module>
#       6 print(f"evaluate a: {evaluate_binary_heap(a, x=2)}")
#       7 print(f"evaluate a: {evaluate_binary_heap(b, x=2)}")
# ----> 8 crossover(a,b)
#
# NameError: name 'crossover' is not defined

# %%
equ = ['nah', "+", 'x', 3]
x = [1,2,3,4,5]
calculate_y(x, equ)
# Out:
# [4, 5, 6, 7, 8]

# %%
def calculate_mse(y, y_hat):
    """
    use np to calculate mse
    """
#     calculated_y = np.array(calculate_y(x_s, equation=equation))
#     calculated_y = [x.astype(float) for x in calculated_y] # cast to np.float
#     y = [n.astype(float) for n in y]
#     y_hat = [n.astype(float) for n in y_hat]
#     print(len(y) == len(y_hat))
    y = np.array(y)
    y_hat = np.array(y_hat)
    mse = np.square(np.subtract(y, y_hat)).mean()
    return mse

# %%
def calc_mse(y, y_hat):
    """
    home-made mse calculation
    """
    errors_sq = []
    tmp = 0
    for i in range(len(y)):
        try:
            e = (y[i] - y_hat[i]) ** 2
            tmp = e
        except TypeError:
#             print(f"y[i] = {y[i]}")
#             print(f"y_hat[i] = {y_hat[i]}")
            pass
        errors_sq.append(tmp)
    return round(sum(errors_sq)/len(errors_sq), 8)

# %%
a = [45,46,34,63,75]
b = [21,64,23,64,23]
print(calc_mse(a,b))
# Out:
# 745.2

# %%
def generate_population(population, depth):
    """
    generate some number of population
    """
    pool = {}
    
    for i in range(population):
        equation = random_generate(depth)
        y_calculated = calculate_y(x_s, equation=equation)
        mse = calc_mse(y_calculated, y_s)
        
        pool[mse] = equation
    
    return pool

# %%
def crossover(parent1, parent2):
    """
    crossover operation
    1. random pick a point at parent1
    2. random pick a point at parent2
    3. completely swap the points and their children
    4. return two trees
    """
    
    p1 = copy.deepcopy(parent1)
    p2 = copy.deepcopy(parent2)
    
    rm_idxs1 = find_all_children(p1) # top node and its grand-grandchildren - random
    rm_idxs2 = find_all_children(p2) # top node and its grand-grandchildren - random
    
#     print(rm_idxs1)
#     print(rm_idxs2)
    
    removed1 = [p1[x] for x in rm_idxs1] 
    removed2 = [p2[x] for x in rm_idxs2]
    
    for idx in rm_idxs1:
        p1[idx] = 'nah'
    
    for idx in rm_idxs2:
        p2[idx] = 'nah' 
        
        
    # if they are in the same length
    if len(removed1) == len(removed2):
        for ele in removed1:
            for i in range(1, len(p2)):
                if p2[i] == "nah":
                    p2[i] = ele
                    break
                    
        for ele in removed2:
            for i in range(1, len(p1)):
                if p1[i] == "nah":
                    p1[i] = ele
                    break
    
    # if not
    elif len(removed1) > len(removed2):

        ptr_rm = 0
        ptr_idx = 0
        while ptr_rm < len(removed1):
            while ptr_idx < len(rm_idxs2): 
                p2[rm_idxs2[ptr_idx]] = removed1[ptr_rm]
                ptr_idx += 1
                ptr_rm += 1
                
            p2.append(removed1[ptr_rm])
            ptr_rm += 1
            
        for ele in removed2:
            for idx in rm_idxs1:
                p1[idx] = ele
                break                   
    else:
        ptr_rm = 0
        ptr_idx = 0
        while ptr_rm < len(removed2):
            while ptr_idx < len(rm_idxs1): 
                p1[rm_idxs1[ptr_idx]] = removed2[ptr_rm]
                ptr_idx += 1
                ptr_rm += 1

            p1.append(removed2[ptr_rm])
            ptr_rm += 1
            
        for ele in removed1:
            for idx in rm_idxs2:
                p2[idx] = ele
                break        

         
    for i in range(1, len(p1)):
        if p1[i] == 'nah':
#             p1[i] = 'x'
            p1[i] = round(random.random() * 10 + 0.1, 4) # not the best
    for i in range(1, len(p2)):
        if p2[i] == 'nah':
#             p2[i] = 'x'
            p2[i] = round(random.random() * 10 + 0.1, 4) # not the best
                
    child1 = p1
    child2 = p2
        
    return [child1, child2]

# %%
def mutate_pool(pool: dict, mutate_rate: float)-> dict:
    """
    mutate a pool of population by given mutation rate
    """
    copied_pool = copy.deepcopy(pool)
    
    new_pool = {}
    
    number = int(len(copied_pool) * mutate_rate)
    
    for i in range(number):
        keys = list(copied_pool.keys())
        random.shuffle(keys)
        mutant = mutate(copied_pool[keys[0]], mutate_rate=1)
        y_hat = calculate_y(x_s, equation=mutant)
        mse = calc_mse(y_s, y_hat)
        new_pool[mse] = mutant
    pool = merge(new_pool, copied_pool)
    return pool

# %%
a = generate_population(population=2, depth=3)
a
# Out:
# {84673.33333333: ['nah', 'x'], 84434.56971456: ['nah', 'cos', 'x', 'x']}

# %%
mutate_pool(pool=a, mutate_rate=1)
# Out:
# {84673.33333333: ['nah', 'x'], 84434.56971456: ['nah', 'cos', 'x', 'x']}

# %%
a = ['nah',1,2,3,4,5,6,7,8,9]
b = ['nah','a', 'b', 'c', 'd', 'e', 'f', 'g']

crossover(a,b)
# Out:
# [['nah', 1, 2, 3, 'd', 5, 6, 7, 4.6806, 9.773],
#  ['nah', 'a', 'b', 'c', 4, 'e', 'f', 'g', 8, 9]]

# %%
def random_search(num, x_s, y_s, depth):
    
    """
    random search
    """
    evaluation = []
    error = []
    final_equation = []
    y_calculated = []
    
    for i in range(num):
        
        if i % 100 == 0:
            print(f"{i/num_evaluation * 100} % complete")

        calculated_y = []
        
        equation = random_generate(depth=depth)
        
        for ele in x_s:
            res = evaluate_binary_heap(equation, x=ele)
            calculated_y.append(res)
            
        calculated_y = np.array(calculated_y)
        try:
            mse = (np.square(y_s - calculated_y)).mean(axis=0)
        except:
            print("raise MSE error")
        
        if len(error) == 0:
            error.append(mse)
            evaluation.append(i)
            final_equation = equation
            y_calculated = calculated_y
            
        elif mse < error[-1]:
            error.append(mse)
            evaluation.append(i)
            final_equation = equation
            y_calculated = calculated_y
            
    return [evaluation, error, final_equation, y_calculated]

# %%
def random_mutation_hill_climber(num, x_s, y_s, depth):
    """
    random hill climber
    """
    
    evaluation = []
    error = []
    final_equation = []
    y_calculated = []
    
    
    first_gen = random_generate(depth=depth)
    y_cal = calculate_y(x_s=x_s, equation=first_gen)
    mse = calculate_mse(y_s, y_cal)
    
    for i in range(0, num):
        
        mutant = mutate(first_gen, mutate_rate=0.01)
        calculated_y = calculate_y(x_s, equation=mutant)
        mse = calculate_mse(calculated_y, y_s)
        
        if len(error) == 0:
            error.append(mse)
            evaluation.append(i)
            final_equation = mutant
            y_calculated = calculated_y

        elif mse < error[-1]:
            error.append(mse)
            evaluation.append(i)
            final_equation = mutant
            y_calculated = calculated_y
            
        if i % 100 == 0:
            print(f"{i/num_evaluation * 100} % complete")
    
    return [evaluation, error, final_equation, y_calculated]

# %%
def random_restart_hill_climber(num_eval, x_s, y_s, depth, num_tries):
    evaluations = []
    errors = []
    final_equation = []
    y_calculated = []
    counter = num_eval
    
    while counter > 0:
        
        first_gen = random_generate(depth=depth)
        y_cal = calculate_y(x_s=x_s, equation=first_gen)
        mse = calculate_mse(y_s, y_cal)
        
        if (num_eval - counter) % 100 == 0:
            print(f"{(num_eval - counter)/num_evaluation*100} % complete")
        
        counter -= 1
    
        if len(errors) == 0:
            errors.append(mse)
            evaluations.append(num_eval - counter)
            final_equation = first_gen
            y_calculated = calculate_y(x_s, equation=first_gen)
        
        while num_tries > 0 and counter > 0:
            
            mutant = mutate(first_gen, mutate_rate=0.01)
            calculated_y = calculate_y(x_s, equation=mutant)
            new_mse = calculate_mse(calculated_y, y_s)
            
            if (num_eval - counter) % 100 == 0:
                print(num_eval - counter)
            
            if new_mse < errors[-1]:
                errors.append(new_mse)
                evaluations.append(num_eval - counter)
                final_equation = mutant
                y_calculated = calculate_y(x_s, mutant)
            else:
                num_tries -= 1
        
        if mse < errors[-1]:
            errors.append(mse)
            evaluations.append(num_eval - counter)
            final_equation = first_gen
            y_calculated = calculate_y(x_s, equation=first_gen)
            
    return [evaluations, errors, final_equation, y_calculated]

# %%
def evol_algo(num_eval, x_s, y_s, depth, init_pop):
    """
    selection 50%
    mutation are built-in to crossover
    """
    
    evaluations = []
    errors = []
    final_equation = []
    y_calculated = []
    
    counter = num_eval

    pool = generate_population(depth=depth, population=init_pop)
    print(f"pool = {len(pool)}")
    num_keys = len(pool)
    try:
        while counter > 0 and num_keys > 0:
            children_pool = {}

            keys = sorted(pool.keys(), reverse=False) 
#             keys = list(pool.keys())
            for i in range(0, len(keys)-1, 2):
                kid1, kid2 = crossover(pool[keys[i]], pool[keys[i+1]])

                y_hat_kid1 = calculate_y(x_s=x_s, equation=kid1)
                y_hat_kid2 = calculate_y(x_s=x_s, equation=kid2)
    #             children_pool[calculate_mse(y_s, y_hat_kid1)] = kid1
    #             children_pool[calculate_mse(y_s, y_hat_kid2)] = kid2

                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid1)] = kid1
                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid2)] = kid2

            print(f"children pool = {len(children_pool)}")

            merge_pool = merge(children_pool, pool)
            print(f"merged pool = {len(merge_pool)}")

            pool = merge_pool

            temp_pool = {}

            keys = sorted(pool.keys(), reverse=False)
            half_keys = keys[0:9*(len(keys)//10)] # selection X%
            num_keys = len(half_keys)
            print(f"# of keys = {num_keys}")

            for i in range(num_keys): 
                temp_pool[keys[i]] = pool[keys[i]]
            print(f"top pool = {len(temp_pool)}")

            lowest_error = min(half_keys)
            print(f"lowest error = {lowest_error}")
            if (len(errors) == 0) or (lowest_error < errors[-1]):
                evaluations.append(num_eval - counter)
                final_equation = temp_pool[lowest_error]
                y_calculated = calculate_y(x_s, final_equation)
                errors.append(lowest_error)

            pool = temp_pool
            counter -= 1

    #         if counter % 10 == 0:
            print(f"counter = {num_eval - counter}")
    except ValueError:
        pass
    return [evaluations, errors, final_equation, y_calculated]

# %%
def evol_algo_div(num_eval, x_s, y_s, depth, init_pop):
    """
    selection 50%
    mutation are built-in to crossover
    adding some random diversity
    """
    
    evaluations = []
    errors = []
    final_equation = []
    y_calculated = []
    
    counter = num_eval

    pool = generate_population(depth=depth, population=init_pop)
    print(f"pool = {len(pool)}")
    num_keys = len(pool)
    try:
        while counter > 0 and num_keys > 0:
            children_pool = {}

            keys = sorted(pool.keys(), reverse=False) 
#             keys = list(pool.keys())
            for i in range(0, len(keys)-1, 2):
                kid1, kid2 = crossover(pool[keys[i]], pool[keys[i+1]])

                y_hat_kid1 = calculate_y(x_s=x_s, equation=kid1)
                y_hat_kid2 = calculate_y(x_s=x_s, equation=kid2)

                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid1)] = kid1
                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid2)] = kid2

            print(f"children pool = {len(children_pool)}")
            
            merge_pool = merge(children_pool, pool)
            print(f"merged pool = {len(merge_pool)}")
            
            pool = merge_pool

            temp_pool = {}

            keys = sorted(pool.keys(), reverse=False)
            half_keys = keys[0:5*(len(keys)//10)] # selection X%
            num_keys = len(half_keys)
            if num_keys < init_pop:
                new_pool = generate_population(depth=depth, population=(init_pop - num_keys)//2)
                temp_pool = merge(temp_pool, new_pool)
            print(f"# of keys = {num_keys}")

            for i in range(num_keys): 
                temp_pool[keys[i]] = pool[keys[i]]
            print(f"top pool = {len(temp_pool)}")

            lowest_error = min(half_keys)
            print(f"lowest error = {lowest_error}")
            if (len(errors) == 0) or (lowest_error < errors[-1]):
                evaluations.append(num_eval - counter)
                final_equation = temp_pool[lowest_error]
                y_calculated = calculate_y(x_s, final_equation)
                errors.append(lowest_error)

            pool = temp_pool
            counter -= 1

    #         if counter % 10 == 0:
            print(f"counter = {num_eval - counter}")
    except ValueError:
        pass
    return [evaluations, errors, final_equation, y_calculated]

# %%
def evol_algo_div_mut(num_eval, x_s, y_s, depth, init_pop, mutate_rate):
    """
    selection 50%
    mutation are built-in to crossover
    adding some random diversity
    adding mutation in the pool
    """
    
    evaluations = []
    errors = []
    final_equation = []
    y_calculated = []
    
    counter = num_eval

    pool = generate_population(depth=depth, population=init_pop)
    print(f"pool = {len(pool)}")
    num_keys = len(pool)
    try:
        while counter > 0 and num_keys > 0:
            children_pool = {}

            keys = sorted(pool.keys(), reverse=False) 
#             keys = list(pool.keys())
            for i in range(0, len(keys)-1, 2):
                kid1, kid2 = crossover(pool[keys[i]], pool[keys[i+1]])

                y_hat_kid1 = calculate_y(x_s=x_s, equation=kid1)
                y_hat_kid2 = calculate_y(x_s=x_s, equation=kid2)

                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid1)] = kid1
                children_pool[calc_mse(y=y_s, y_hat=y_hat_kid2)] = kid2

            print(f"children pool = {len(children_pool)}")
            
            merge_pool = merge(children_pool, pool)
            
            mutated_pool = mutate_pool(pool=merge_pool, mutate_rate=mutate_rate)
#             print(f"merged pool = {len(merge_pool)}")
            
            pool = mutated_pool

            temp_pool = {}

            keys = sorted(pool.keys(), reverse=False)
            half_keys = keys[0:5*(len(keys)//10)] # selection X%
            num_keys = len(half_keys)
            if num_keys < init_pop:
                new_pool = generate_population(depth=depth, population=(init_pop - num_keys)//2)
                temp_pool = merge(temp_pool, new_pool)
#             print(f"# of keys = {num_keys}")

            for i in range(num_keys): 
                temp_pool[keys[i]] = pool[keys[i]]
#             print(f"top pool = {len(temp_pool)}")

            lowest_error = keys[0]
            print(f"lowest error = {lowest_error}")
            if (len(errors) == 0) or (lowest_error < errors[-1]):
                evaluations.append(num_eval - counter)
                final_equation = temp_pool[lowest_error]
                y_calculated = calculate_y(x_s, final_equation)
                errors.append(lowest_error)

            pool = temp_pool
            counter -= 1

    #         if counter % 10 == 0:
            print(f"counter = {num_eval - counter}")
    except ValueError:
        pass
    return [evaluations, errors, final_equation, y_calculated]

# %%
res_ea_div_mut = evol_algo_div_mut(num_eval=num_evaluation, x_s=x_s, y_s=y_s, depth=depth, init_pop=20, mutate_rate=0.5)
# Out:
# <ipython-input-11-f83ed01f3e61>:28: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]
# <ipython-input-11-f83ed01f3e61>:28: RuntimeWarning: divide by zero encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]
# <ipython-input-11-f83ed01f3e61>:36: RuntimeWarning: invalid value encountered in cos
#   bh[i] = np.cos(bh[2*i])
# <ipython-input-11-f83ed01f3e61>:32: RuntimeWarning: invalid value encountered in sin
#   bh[i] = np.sin(bh[2*i])
# <ipython-input-11-f83ed01f3e61>:24: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] * bh[2*i+1]
# pool = 20
# children pool = 20
# lowest error = 62485.36072506
# counter = 1
# children pool = 20
# lowest error = 52846.53790913
# counter = 2
# children pool = 19
# lowest error = 44592.84845909
# counter = 3
# children pool = 15
# lowest error = 20494.95895263
# counter = 4
# children pool = 19
# lowest error = 20494.95895263
# counter = 5
# children pool = 23
# lowest error = 244.35425828
# counter = 6
# children pool = 23
# lowest error = 244.35425828
# counter = 7
# children pool = 22
# lowest error = 216.66666667
# counter = 8
# children pool = 21
# lowest error = 216.66666667
# counter = 9
# children pool = 22
# lowest error = nan
# counter = 10
# children pool = 24
# lowest error = 216.66666667
# counter = 11
# children pool = 24
# lowest error = nan
# counter = 12
# children pool = 20
# lowest error = nan
# counter = 13
# children pool = 20
# lowest error = 0.3908834
# counter = 14
# children pool = 18
# lowest error = 0.3908834
# counter = 15
# children pool = 18
# lowest error = 0.03579664
# counter = 16
# children pool = 19
# lowest error = 0.03579664
# counter = 17
# children pool = 19
# lowest error = 0.03579664
# counter = 18
# children pool = 17
# lowest error = 0.03579664
# counter = 19
# children pool = 18
# lowest error = 0.03579664
# counter = 20
# children pool = 14
# lowest error = nan
# counter = 21
# children pool = 16
# lowest error = 0.03579664
# counter = 22
# children pool = 16
# lowest error = 0.03579664
# counter = 23
# children pool = 16
# lowest error = 0.03579664
# counter = 24
# children pool = 15
# lowest error = nan
# counter = 25
# children pool = 14
# lowest error = 0.03579664
# counter = 26
# children pool = 15
# lowest error = 0.03579664
# counter = 27
# children pool = 16
# lowest error = 0.03579664
# counter = 28
# children pool = 13
# lowest error = 0.03579664
# counter = 29
# children pool = 15
# lowest error = 0.03579664
# counter = 30
# children pool = 13
# lowest error = 0.03579664
# counter = 31
# children pool = 14
# lowest error = 0.03579664
# counter = 32
# children pool = 13
# lowest error = 0.03579664
# counter = 33
# children pool = 15
# lowest error = 0.03579664
# counter = 34
# children pool = 14
# lowest error = 0.03579664
# counter = 35
# children pool = 13
# lowest error = 0.0
# counter = 36
# children pool = 15
# lowest error = 0.0
# counter = 37
# children pool = 14
# lowest error = 0.0
# counter = 38
# children pool = 15
# lowest error = 0.0
# counter = 39
# children pool = 14
# lowest error = 0.0
# counter = 40
# children pool = 14
# lowest error = 0.0
# counter = 41
# children pool = 14
# lowest error = 0.0
# counter = 42
# children pool = 12
# lowest error = 0.0
# counter = 43
# children pool = 14
# lowest error = 0.0
# counter = 44
# children pool = 13
# lowest error = 0.0
# counter = 45
# children pool = 11
# lowest error = 0.0
# counter = 46
# children pool = 13
# lowest error = 0.0
# counter = 47
# children pool = 11
# lowest error = 0.0
# counter = 48
# children pool = 13
# lowest error = nan
# counter = 49
# children pool = 16
# lowest error = 0.32027887
# counter = 50
# children pool = 15
# lowest error = 0.01020874
# counter = 51
# children pool = 16
# lowest error = 0.01020874
# counter = 52
# children pool = 18
# lowest error = 0.01020874
# counter = 53
# children pool = 17
# lowest error = nan
# counter = 54
# children pool = 18
# lowest error = 0.01020874
# counter = 55
# children pool = 19
# lowest error = 0.01020874
# counter = 56
# children pool = 17
# lowest error = 0.01020874
# counter = 57
# children pool = 16
# lowest error = 0.0
# counter = 58
# children pool = 15
# lowest error = 0.0
# counter = 59
# children pool = 15
# lowest error = 0.0
# counter = 60
# children pool = 13
# lowest error = 0.0
# counter = 61
# children pool = 15
# lowest error = 0.0
# counter = 62
# children pool = 16
# lowest error = 0.0
# counter = 63
# children pool = 14
# lowest error = 0.0
# counter = 64
# children pool = 16
# lowest error = 0.0
# counter = 65
# children pool = 15
# lowest error = 0.0
# counter = 66
# children pool = 14
# lowest error = 0.0
# counter = 67
# children pool = 12
# lowest error = 0.0
# counter = 68
# children pool = 15
# lowest error = 0.0
# counter = 69
# children pool = 15
# lowest error = 0.0
# counter = 70
# children pool = 15
# lowest error = 0.0
# counter = 71
# children pool = 15
# lowest error = 0.0
# counter = 72
# children pool = 13
# lowest error = 0.0
# counter = 73
# children pool = 14
# lowest error = 0.0
# counter = 74
# children pool = 14
# lowest error = 0.0
# counter = 75
# children pool = 15
# lowest error = 0.0
# counter = 76
# children pool = 16
# lowest error = 0.0
# counter = 77
# children pool = 16
# lowest error = 0.0
# counter = 78
# children pool = 15
# lowest error = 0.0
# counter = 79
# children pool = 15
# lowest error = 0.0
# counter = 80
# children pool = 13
# lowest error = 0.0
# counter = 81
# children pool = 14
# lowest error = 0.0
# counter = 82
# children pool = 15
# lowest error = 0.0
# counter = 83
# children pool = 15
# lowest error = 0.0
# counter = 84
# children pool = 13
# lowest error = 0.0
# counter = 85
# children pool = 13
# lowest error = 0.0
# counter = 86
# children pool = 14
# lowest error = 0.0
# counter = 87
# children pool = 13
# lowest error = 0.0
# counter = 88
# children pool = 13
# lowest error = 0.0
# counter = 89
# children pool = 15
# lowest error = 0.0
# counter = 90
# children pool = 14
# lowest error = 0.0
# counter = 91
# children pool = 14
# lowest error = 0.0
# counter = 92
# children pool = 15
# lowest error = 0.0
# counter = 93
# children pool = 12
# lowest error = 0.0
# counter = 94
# children pool = 13
# lowest error = 0.0
# counter = 95
# children pool = 13
# lowest error = 0.0
# counter = 96
# children pool = 15
# lowest error = 0.0
# counter = 97
# children pool = 14
# lowest error = 0.0
# counter = 98
# children pool = 15
# lowest error = 0.0
# counter = 99
# children pool = 13
# lowest error = 0.0
# counter = 100
# children pool = 14
# lowest error = 0.0
# counter = 101
# children pool = 14
# lowest error = 0.0
# counter = 102
# children pool = 16
# lowest error = 0.0
# counter = 103
# children pool = 13
# lowest error = 0.0
# counter = 104
# children pool = 15
# lowest error = 0.0
# counter = 105
# children pool = 18
# lowest error = 0.0
# counter = 106
# children pool = 16
# lowest error = 0.0
# counter = 107
# children pool = 19
# lowest error = 0.0
# counter = 108
# children pool = 17
# lowest error = 0.0
# counter = 109
# children pool = 16
# lowest error = 0.0
# counter = 110
# children pool = 18
# lowest error = 0.0
# counter = 111
# children pool = 15
# lowest error = 0.0
# counter = 112
# children pool = 12
# lowest error = 0.0
# counter = 113
# children pool = 13
# lowest error = 0.0
# counter = 114
# children pool = 12
# lowest error = 0.0
# counter = 115
# children pool = 11
# lowest error = 0.0
# counter = 116
# children pool = 13
# lowest error = 0.0
# counter = 117
# children pool = 13
# lowest error = nan
# counter = 118
# children pool = 14
# lowest error = nan
# counter = 119
# children pool = 12
# lowest error = 0.0
# counter = 120
# children pool = 14
# lowest error = 0.0
# counter = 121
# children pool = 14
# lowest error = 0.0
# counter = 122
# children pool = 15
# lowest error = 0.0
# counter = 123
# children pool = 14
# lowest error = 0.0
# counter = 124
# children pool = 14
# lowest error = 0.0
# counter = 125
# children pool = 15
# lowest error = 0.0
# counter = 126
# children pool = 13
# lowest error = 0.0
# counter = 127
# children pool = 13
# lowest error = 0.0
# counter = 128
# children pool = 13
# lowest error = 0.0
# counter = 129
# children pool = 8
# lowest error = 0.0
# counter = 130
# children pool = 10
# lowest error = 0.0
# counter = 131
# children pool = 14
# lowest error = 0.0
# counter = 132
# children pool = 14
# lowest error = 0.0
# counter = 133
# children pool = 14
# lowest error = 0.0
# counter = 134
# children pool = 12
# lowest error = 0.0
# counter = 135
# children pool = 14
# lowest error = 0.0
# counter = 136
# children pool = 13
# lowest error = 0.0
# counter = 137
# children pool = 13
# lowest error = 0.0
# counter = 138
# children pool = 13
# lowest error = 0.0
# counter = 139
# children pool = 14
# lowest error = 0.0
# counter = 140
# children pool = 14
# lowest error = 0.0
# counter = 141
# children pool = 13
# lowest error = 0.0
# counter = 142
# children pool = 15
# lowest error = 0.0
# counter = 143
# children pool = 12
# lowest error = 0.0
# counter = 144
# children pool = 12
# lowest error = 0.0
# counter = 145
# children pool = 12
# lowest error = 0.0
# counter = 146
# children pool = 13
# lowest error = 0.0
# counter = 147
# children pool = 15
# lowest error = 0.0
# counter = 148
# children pool = 16
# lowest error = 0.0
# counter = 149
# children pool = 14
# lowest error = 0.0
# counter = 150
# children pool = 13
# lowest error = 0.0
# counter = 151
# children pool = 13
# lowest error = 0.0
# counter = 152
# children pool = 13
# lowest error = 0.0
# counter = 153
# children pool = 10
# lowest error = 0.0
# counter = 154
# children pool = 14
# lowest error = 0.0
# counter = 155
# children pool = 13
# lowest error = 0.0
# counter = 156
# children pool = 14
# lowest error = 0.0
# counter = 157
# children pool = 14
# lowest error = 0.0
# counter = 158
# children pool = 12
# lowest error = 0.0
# counter = 159
# children pool = 14
# lowest error = 0.0
# counter = 160
# children pool = 12
# lowest error = 0.0
# counter = 161
# children pool = 15
# lowest error = 0.0
# counter = 162
# children pool = 14
# lowest error = 0.0
# counter = 163
# children pool = 15
# lowest error = 0.0
# counter = 164
# children pool = 12
# lowest error = 0.0
# counter = 165
# children pool = 14
# lowest error = nan
# counter = 166
# children pool = 13
# lowest error = 0.0
# counter = 167
# children pool = 15
# lowest error = 0.0
# counter = 168
# children pool = 15
# lowest error = 0.0
# counter = 169
# children pool = 15
# lowest error = 0.0
# counter = 170
# children pool = 15
# lowest error = 0.0
# counter = 171
# children pool = 14
# lowest error = 0.0
# counter = 172
# children pool = 12
# lowest error = 0.0
# counter = 173
# children pool = 14
# lowest error = 0.0
# counter = 174
# children pool = 12
# lowest error = 0.0
# counter = 175
# children pool = 13
# lowest error = 0.0
# counter = 176
# children pool = 14
# lowest error = nan
# counter = 177
# children pool = 14
# lowest error = 0.0
# counter = 178
# children pool = 11
# lowest error = 0.0
# counter = 179
# children pool = 11
# lowest error = 0.0
# counter = 180
# children pool = 14
# lowest error = 0.0
# counter = 181
# children pool = 13
# lowest error = 0.0
# counter = 182
# children pool = 11
# lowest error = 0.0
# counter = 183
# children pool = 9
# lowest error = 0.0
# counter = 184
# children pool = 13
# lowest error = 0.0
# counter = 185
# children pool = 12
# lowest error = 0.0
# counter = 186
# children pool = 14
# lowest error = nan
# counter = 187
# children pool = 16
# lowest error = 0.0
# counter = 188
# children pool = 13
# lowest error = nan
# counter = 189
# children pool = 14
# lowest error = 0.0
# counter = 190
# children pool = 12
# lowest error = 0.0
# counter = 191
# children pool = 10
# lowest error = 0.0
# counter = 192
# children pool = 13
# lowest error = 0.0
# counter = 193
# children pool = 13
# lowest error = 0.0
# counter = 194
# children pool = 13
# lowest error = 0.0
# counter = 195
# children pool = 13
# lowest error = 0.0
# counter = 196
# children pool = 12
# lowest error = 0.0
# counter = 197
# children pool = 14
# lowest error = 0.0
# counter = 198
# children pool = 14
# lowest error = 0.0
# counter = 199
# children pool = 16
# lowest error = 0.0
# counter = 200
# children pool = 16
# lowest error = 0.0
# counter = 201
# children pool = 13
# lowest error = 0.0
# counter = 202
# children pool = 14
# lowest error = 0.0
# counter = 203
# children pool = 14
# lowest error = 0.0
# counter = 204
# children pool = 12
# lowest error = 0.0
# counter = 205
# children pool = 12
# lowest error = 0.0
# counter = 206
# children pool = 12
# lowest error = 0.0
# counter = 207
# children pool = 13
# lowest error = 0.0
# counter = 208
# children pool = 13
# lowest error = 0.0
# counter = 209
# children pool = 12
# lowest error = 0.0
# counter = 210
# children pool = 14
# lowest error = 0.0
# counter = 211
# children pool = 13
# lowest error = 0.0
# counter = 212
# children pool = 13
# lowest error = 0.0
# counter = 213
# children pool = 13
# lowest error = 0.0
# counter = 214
# children pool = 13
# lowest error = 0.0
# counter = 215
# children pool = 16
# lowest error = 0.0
# counter = 216
# children pool = 15
# lowest error = 0.0
# counter = 217
# children pool = 13
# lowest error = 0.0
# counter = 218
# children pool = 13
# lowest error = 0.0
# counter = 219
# children pool = 11
# lowest error = 0.0
# counter = 220
# children pool = 14
# lowest error = 0.0
# counter = 221
# children pool = 14
# lowest error = 0.0
# counter = 222
# children pool = 13
# lowest error = 0.0
# counter = 223
# children pool = 13
# lowest error = 0.0
# counter = 224
# children pool = 12
# lowest error = 0.0
# counter = 225
# children pool = 14
# lowest error = nan
# counter = 226
# children pool = 13
# lowest error = 0.0
# counter = 227
# children pool = 11
# lowest error = 0.0
# counter = 228
# children pool = 13
# lowest error = 0.0
# counter = 229
# children pool = 13
# lowest error = 0.0
# counter = 230
# children pool = 11
# lowest error = nan
# counter = 231
# children pool = 13
# lowest error = 0.0
# counter = 232
# children pool = 14
# lowest error = 0.0
# counter = 233
# children pool = 13
# lowest error = 0.0
# counter = 234
# children pool = 14
# lowest error = 0.0
# counter = 235
# children pool = 14
# lowest error = nan
# counter = 236
# children pool = 14
# lowest error = nan
# counter = 237
# children pool = 14
# lowest error = 0.0
# counter = 238
# children pool = 13
# lowest error = 0.0
# counter = 239
# children pool = 12
# lowest error = nan
# counter = 240
# children pool = 13
# lowest error = 0.0
# counter = 241
# children pool = 13
# lowest error = 0.0
# counter = 242
# children pool = 14
# lowest error = 0.0
# counter = 243
# children pool = 15
# lowest error = 0.0
# counter = 244
# children pool = 13
# lowest error = 0.0
# counter = 245
# children pool = 13
# lowest error = 0.0
# counter = 246
# children pool = 15
# lowest error = 0.0
# counter = 247
# children pool = 15
# lowest error = 0.0
# counter = 248
# children pool = 16
# lowest error = 0.0
# counter = 249
# children pool = 16
# lowest error = 0.0
# counter = 250
# children pool = 16
# lowest error = 0.0
# counter = 251
# children pool = 16
# lowest error = nan
# counter = 252
# children pool = 16
# lowest error = nan
# counter = 253
# children pool = 15
# lowest error = 0.0
# counter = 254
# children pool = 14
# lowest error = 0.0
# counter = 255
# children pool = 13
# lowest error = 0.0
# counter = 256
# children pool = 14
# lowest error = 0.0
# counter = 257
# children pool = 13
# lowest error = 0.0
# counter = 258
# children pool = 14
# lowest error = 0.0
# counter = 259
# children pool = 14
# lowest error = 0.0
# counter = 260
# children pool = 15
# lowest error = 0.0
# counter = 261
# children pool = 14
# lowest error = 0.0
# counter = 262
# children pool = 14
# lowest error = 0.0
# counter = 263
# children pool = 14
# lowest error = 0.0
# counter = 264
# children pool = 13
# lowest error = 0.0
# counter = 265
# children pool = 14
# lowest error = 0.0
# counter = 266
# children pool = 14
# lowest error = 0.0
# counter = 267
# children pool = 12
# lowest error = 0.0
# counter = 268
# children pool = 13
# lowest error = 0.0
# counter = 269
# children pool = 15
# lowest error = 0.0
# counter = 270
# children pool = 15
# lowest error = 0.0
# counter = 271
# children pool = 15
# lowest error = nan
# counter = 272
# children pool = 14
# lowest error = 0.0
# counter = 273
# children pool = 13
# lowest error = 0.0
# counter = 274
# children pool = 14
# lowest error = 0.0
# counter = 275
# children pool = 14
# lowest error = 0.0
# counter = 276
# children pool = 14
# <ipython-input-11-f83ed01f3e61>:20: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] - bh[2*i+1]
# lowest error = 0.0
# counter = 277
# children pool = 15
# lowest error = 0.0
# counter = 278
# children pool = 15
# lowest error = 0.0
# counter = 279
# children pool = 12
# lowest error = nan
# counter = 280
# children pool = 12
# lowest error = 0.0
# counter = 281
# children pool = 13
# lowest error = nan
# counter = 282
# children pool = 12
# lowest error = 0.0
# counter = 283
# children pool = 13
# lowest error = 0.0
# counter = 284
# children pool = 12
# lowest error = 0.0
# counter = 285
# children pool = 14
# lowest error = 0.0
# counter = 286
# children pool = 15
# lowest error = 0.0
# counter = 287
# children pool = 13
# lowest error = 0.0
# counter = 288
# children pool = 14
# lowest error = 0.0
# counter = 289
# children pool = 13
# lowest error = 0.0
# counter = 290
# children pool = 14
# lowest error = 0.0
# counter = 291
# children pool = 13
# lowest error = 0.0
# counter = 292
# children pool = 15
# lowest error = 0.0
# counter = 293
# children pool = 14
# lowest error = 0.0
# counter = 294
# children pool = 11
# lowest error = nan
# counter = 295
# children pool = 14
# lowest error = 0.0
# counter = 296
# children pool = 15
# lowest error = 0.0
# counter = 297
# children pool = 16
# lowest error = 0.0
# counter = 298
# children pool = 16
# lowest error = 0.0
# counter = 299
# children pool = 13
# lowest error = 0.0
# counter = 300
# children pool = 13
# lowest error = 0.0
# counter = 301
# children pool = 13
# lowest error = 0.0
# counter = 302
# children pool = 14
# lowest error = 0.0
# counter = 303
# children pool = 14
# lowest error = 0.0
# counter = 304
# children pool = 14
# lowest error = 0.0
# counter = 305
# children pool = 14
# lowest error = 0.0
# counter = 306
# children pool = 11
# lowest error = 0.0
# counter = 307
# children pool = 14
# lowest error = 0.0
# counter = 308
# children pool = 14
# lowest error = 0.0
# counter = 309
# children pool = 13
# lowest error = 0.0
# counter = 310
# children pool = 14
# lowest error = 0.0
# counter = 311
# children pool = 13
# lowest error = 0.0
# counter = 312
# children pool = 13
# lowest error = 0.0
# counter = 313
# children pool = 12
# lowest error = 0.0
# counter = 314
# children pool = 13
# lowest error = 0.0
# counter = 315
# children pool = 14
# lowest error = 0.0
# counter = 316
# children pool = 14
# lowest error = 0.0
# counter = 317
# children pool = 16
# lowest error = 0.0
# counter = 318
# children pool = 14
# lowest error = 0.0
# counter = 319
# children pool = 15
# lowest error = 0.0
# counter = 320
# children pool = 15
# lowest error = 0.0
# counter = 321
# children pool = 15
# lowest error = 0.0
# counter = 322
# children pool = 15
# lowest error = 0.0
# counter = 323
# children pool = 13
# lowest error = 0.0
# counter = 324
# children pool = 11
# lowest error = 0.0
# counter = 325
# children pool = 13
# lowest error = 0.0
# counter = 326
# children pool = 12
# lowest error = 0.0
# counter = 327
# children pool = 12
# lowest error = 0.0
# counter = 328
# children pool = 13
# lowest error = 0.0
# counter = 329
# children pool = 11
# lowest error = 0.0
# counter = 330
# children pool = 10
# lowest error = 0.0
# counter = 331
# children pool = 13
# lowest error = 0.0
# counter = 332
# children pool = 14
# lowest error = 0.0
# counter = 333
# children pool = 14
# lowest error = 0.0
# counter = 334
# children pool = 14
# lowest error = 0.0
# counter = 335
# children pool = 14
# lowest error = 0.0
# counter = 336
# children pool = 14
# lowest error = 0.0
# counter = 337
# children pool = 14
# lowest error = 0.0
# counter = 338
# children pool = 12
# lowest error = 0.0
# counter = 339
# children pool = 13
# lowest error = 0.0
# counter = 340
# children pool = 12
# lowest error = 0.0
# counter = 341
# children pool = 13
# lowest error = 0.0
# counter = 342
# children pool = 13
# lowest error = 0.0
# counter = 343
# children pool = 16
# lowest error = 0.0
# counter = 344
# children pool = 14
# lowest error = 0.0
# counter = 345
# children pool = 16
# lowest error = 0.0
# counter = 346
# children pool = 13
# lowest error = nan
# counter = 347
# children pool = 12
# lowest error = 3.99e-06
# counter = 348
# children pool = 13
# lowest error = 3.99e-06
# counter = 349
# children pool = 14
# lowest error = 3.99e-06
# counter = 350
# children pool = 12
# lowest error = 3.99e-06
# counter = 351
# children pool = 12
# lowest error = nan
# counter = 352
# children pool = 13
# lowest error = 3.99e-06
# counter = 353
# children pool = 13
# lowest error = 0.0
# counter = 354
# children pool = 15
# lowest error = 0.0
# counter = 355
# children pool = 14
# lowest error = 0.0
# counter = 356
# children pool = 13
# lowest error = 0.0
# counter = 357
# children pool = 14
# lowest error = nan
# counter = 358
# children pool = 14
# lowest error = 0.0
# counter = 359
# children pool = 11
# lowest error = 0.0
# counter = 360
# children pool = 13
# lowest error = 0.0
# counter = 361
# children pool = 13
# lowest error = 0.0
# counter = 362
# children pool = 10
# lowest error = nan
# counter = 363
# children pool = 13
# lowest error = 0.0
# counter = 364
# children pool = 13
# lowest error = 0.0
# counter = 365
# children pool = 12
# lowest error = 0.0
# counter = 366
# children pool = 13
# lowest error = 0.0
# counter = 367
# children pool = 14
# lowest error = 0.0
# counter = 368
# children pool = 13
# lowest error = 0.0
# counter = 369
# children pool = 13
# lowest error = 0.0
# counter = 370
# children pool = 13
# lowest error = 0.0
# counter = 371
# children pool = 16
# lowest error = 0.0
# counter = 372
# children pool = 14
# lowest error = 0.0
# counter = 373
# children pool = 14
# lowest error = 0.0
# counter = 374
# children pool = 15
# lowest error = nan
# counter = 375
# children pool = 14
# lowest error = 0.0
# counter = 376
# children pool = 13
# lowest error = 0.0
# counter = 377
# children pool = 14
# lowest error = 0.0
# counter = 378
# children pool = 11
# lowest error = 0.0
# counter = 379
# children pool = 12
# lowest error = 0.0
# counter = 380
# children pool = 14
# lowest error = 3.99e-06
# counter = 381
# children pool = 13
# lowest error = 3.99e-06
# counter = 382
# children pool = 14
# lowest error = 3.99e-06
# counter = 383
# children pool = 15
# lowest error = 3.99e-06
# counter = 384
# children pool = 16
# lowest error = 3.99e-06
# counter = 385
# children pool = 15
# lowest error = 3.99e-06
# counter = 386
# children pool = 15
# lowest error = 3.99e-06
# counter = 387
# children pool = 17
# lowest error = 3.99e-06
# counter = 388
# children pool = 16
# lowest error = 3.99e-06
# counter = 389
# children pool = 15
# lowest error = 3.99e-06
# counter = 390
# children pool = 12
# lowest error = 3.99e-06
# counter = 391
# children pool = 13
# lowest error = 3.99e-06
# counter = 392
# children pool = 13
# lowest error = nan
# counter = 393
# children pool = 12
# lowest error = nan
# counter = 394
# children pool = 15
# lowest error = 0.0
# counter = 395
# children pool = 16
# lowest error = 0.0
# counter = 396
# children pool = 15
# lowest error = 0.0
# counter = 397
# children pool = 15
# lowest error = 0.0
# counter = 398
# children pool = 14
# lowest error = nan
# counter = 399
# children pool = 13
# lowest error = 0.0
# counter = 400
# children pool = 13
# lowest error = 0.0
# counter = 401
# children pool = 14
# lowest error = 0.0
# counter = 402
# children pool = 15
# lowest error = 0.0
# counter = 403
# children pool = 14
# lowest error = 0.0
# counter = 404
# children pool = 14
# lowest error = 0.0
# counter = 405
# children pool = 14
# lowest error = 0.0
# counter = 406
# children pool = 14
# lowest error = 0.0
# counter = 407
# children pool = 15
# lowest error = 0.0
# counter = 408
# children pool = 16
# lowest error = 0.0
# counter = 409
# children pool = 12
# lowest error = 0.0
# counter = 410
# children pool = 15
# lowest error = 0.0
# counter = 411
# children pool = 16
# lowest error = 0.0
# counter = 412
# children pool = 15
# lowest error = 0.0
# counter = 413
# children pool = 13
# lowest error = 0.0
# counter = 414
# children pool = 12
# lowest error = nan
# counter = 415
# children pool = 15
# lowest error = nan
# counter = 416
# children pool = 13
# lowest error = 0.0
# counter = 417
# children pool = 12
# lowest error = 0.0
# counter = 418
# children pool = 14
# lowest error = 0.0
# counter = 419
# children pool = 14
# lowest error = 0.0
# counter = 420
# children pool = 13
# lowest error = 0.0
# counter = 421
# children pool = 11
# lowest error = 0.0
# counter = 422
# children pool = 13
# lowest error = 0.0
# counter = 423
# children pool = 15
# lowest error = 0.0
# counter = 424
# children pool = 15
# lowest error = 0.0
# counter = 425
# children pool = 12
# lowest error = 0.0
# counter = 426
# children pool = 14
# lowest error = 0.0
# counter = 427
# children pool = 12
# lowest error = 0.0
# counter = 428
# children pool = 13
# lowest error = 0.0
# counter = 429
# children pool = 11
# lowest error = 0.0
# counter = 430
# children pool = 13
# lowest error = 0.0
# counter = 431
# children pool = 12
# lowest error = 0.0
# counter = 432
# children pool = 13
# lowest error = 0.0
# counter = 433
# children pool = 14
# lowest error = 0.0
# counter = 434
# children pool = 14
# lowest error = 0.0
# counter = 435
# children pool = 14
# lowest error = nan
# counter = 436
# children pool = 14
# lowest error = 0.0
# counter = 437
# children pool = 13
# lowest error = nan
# counter = 438
# children pool = 11
# lowest error = 0.0
# counter = 439
# children pool = 12
# lowest error = 0.0
# counter = 440
# children pool = 13
# lowest error = 0.0
# counter = 441
# children pool = 15
# lowest error = 0.0
# counter = 442
# children pool = 14
# lowest error = 0.0
# counter = 443
# children pool = 14
# lowest error = 0.0
# counter = 444
# children pool = 15
# lowest error = 0.0
# counter = 445
# children pool = 15
# lowest error = nan
# counter = 446
# children pool = 14
# lowest error = 0.0
# counter = 447
# children pool = 15
# lowest error = 0.0
# counter = 448
# children pool = 13
# lowest error = 0.0
# counter = 449
# children pool = 12
# lowest error = 0.0
# counter = 450
# children pool = 13
# lowest error = 0.0
# counter = 451
# children pool = 13
# lowest error = 0.0
# counter = 452
# children pool = 14
# lowest error = 0.0
# counter = 453
# children pool = 13
# lowest error = 0.0
# counter = 454
# children pool = 14
# lowest error = 0.0
# counter = 455
# children pool = 15
# lowest error = 0.0
# counter = 456
# children pool = 14
# lowest error = 0.0
# counter = 457
# children pool = 12
# lowest error = 0.0
# counter = 458
# children pool = 15
# lowest error = 0.0
# counter = 459
# children pool = 14
# lowest error = 0.0
# counter = 460
# children pool = 13
# lowest error = 0.0
# counter = 461
# children pool = 14
# lowest error = 0.0
# counter = 462
# children pool = 12
# lowest error = 0.0
# counter = 463
# children pool = 12
# lowest error = 0.0
# counter = 464
# children pool = 14
# lowest error = nan
# counter = 465
# children pool = 15
# lowest error = 0.0
# counter = 466
# children pool = 14
# lowest error = 0.0
# counter = 467
# children pool = 16
# lowest error = 0.0
# counter = 468
# children pool = 20
# lowest error = 0.0
# counter = 469
# children pool = 15
# lowest error = 0.0
# counter = 470
# children pool = 13
# lowest error = 0.0
# counter = 471
# children pool = 15
# lowest error = 0.0
# counter = 472
# children pool = 14
# lowest error = 0.0
# counter = 473
# children pool = 14
# lowest error = 0.0
# counter = 474
# children pool = 15
# lowest error = 0.0
# counter = 475
# children pool = 12
# lowest error = 0.0
# counter = 476
# children pool = 14
# lowest error = 0.0
# counter = 477
# children pool = 12
# lowest error = 0.0
# counter = 478
# children pool = 15
# lowest error = 0.0
# counter = 479
# children pool = 14
# lowest error = 0.0
# counter = 480
# children pool = 16
# lowest error = 0.0
# counter = 481
# children pool = 14
# lowest error = 0.0
# counter = 482
# children pool = 14
# lowest error = 0.0
# counter = 483
# children pool = 16
# lowest error = 0.0
# counter = 484
# children pool = 17
# lowest error = 0.0
# counter = 485
# children pool = 15
# lowest error = 0.0
# counter = 486
# children pool = 14
# lowest error = 0.0
# counter = 487
# children pool = 14
# lowest error = 0.0
# counter = 488
# children pool = 15
# lowest error = 0.0
# counter = 489
# children pool = 15
# lowest error = 0.0
# counter = 490
# children pool = 13
# lowest error = 0.0
# counter = 491
# children pool = 14
# lowest error = 0.0
# counter = 492
# children pool = 14
# lowest error = 0.0
# counter = 493
# children pool = 14
# lowest error = 0.0
# counter = 494
# children pool = 16
# lowest error = 0.0
# counter = 495
# children pool = 13
# lowest error = 0.0
# counter = 496
# children pool = 16
# lowest error = 0.0
# counter = 497
# children pool = 16
# lowest error = 0.0
# counter = 498
# children pool = 20
# lowest error = 0.0
# counter = 499
# children pool = 16
# lowest error = 0.0
# counter = 500
# children pool = 17
# lowest error = 0.0
# counter = 501
# children pool = 20
# lowest error = 0.0
# counter = 502
# children pool = 18
# lowest error = 0.0
# counter = 503
# children pool = 18
# lowest error = 0.0
# counter = 504
# children pool = 19
# lowest error = 0.0
# counter = 505
# children pool = 18
# lowest error = 0.0
# counter = 506
# children pool = 22
# lowest error = 0.0
# counter = 507
# children pool = 25
# lowest error = 0.0
# counter = 508
# children pool = 29
# lowest error = nan
# counter = 509
# children pool = 27
# lowest error = 0.0
# counter = 510
# children pool = 29
# lowest error = 0.0
# counter = 511
# children pool = 33
# lowest error = 0.01169938
# counter = 512
# children pool = 33
# lowest error = nan
# counter = 513
# children pool = 34
# lowest error = 0.01169938
# counter = 514
# children pool = 34
# lowest error = 0.01169938
# counter = 515
# children pool = 33
# lowest error = 0.00519046
# counter = 516
# children pool = 32
# lowest error = 0.00519046
# counter = 517
# children pool = 29
# lowest error = 0.00519046
# counter = 518
# children pool = 21
# lowest error = nan
# counter = 519
# children pool = 19
# lowest error = nan
# counter = 520
# children pool = 21
# lowest error = 0.00519046
# counter = 521
# children pool = 22
# lowest error = 0.00519046
# counter = 522
# children pool = 23
# lowest error = 0.00519046
# counter = 523
# children pool = 21
# lowest error = 0.00519046
# counter = 524
# children pool = 19
# lowest error = 0.00519046
# counter = 525
# children pool = 20
# lowest error = 0.00519046
# counter = 526
# children pool = 18
# lowest error = 0.00059526
# counter = 527
# children pool = 18
# lowest error = 0.00059526
# counter = 528
# children pool = 16
# lowest error = nan
# counter = 529
# children pool = 14
# lowest error = 0.0
# counter = 530
# children pool = 14
# lowest error = 0.0
# counter = 531
# children pool = 15
# lowest error = 0.0
# counter = 532
# children pool = 16
# lowest error = 0.0
# counter = 533
# children pool = 18
# lowest error = nan
# counter = 534
# children pool = 18
# lowest error = nan
# counter = 535
# children pool = 19
# lowest error = 0.0
# counter = 536
# children pool = 18
# lowest error = nan
# counter = 537
# children pool = 19
# lowest error = 0.0
# counter = 538
# children pool = 16
# lowest error = 0.0
# counter = 539
# children pool = 19
# lowest error = 0.0
# counter = 540
# children pool = 19
# lowest error = 0.0
# counter = 541
# children pool = 16
# lowest error = 0.0
# counter = 542
# children pool = 16
# lowest error = 0.0
# counter = 543
# children pool = 15
# lowest error = 0.0
# counter = 544
# children pool = 16
# lowest error = 0.0
# counter = 545
# children pool = 18
# lowest error = 0.0
# counter = 546
# children pool = 19
# lowest error = 0.0
# counter = 547
# children pool = 17
# lowest error = nan
# counter = 548
# children pool = 18
# lowest error = 0.0
# counter = 549
# <ipython-input-11-f83ed01f3e61>:16: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] + bh[2*i+1]
# children pool = 19
# lowest error = nan
# counter = 550
# children pool = 19
# lowest error = 0.0
# counter = 551
# children pool = 23
# lowest error = 0.0
# counter = 552
# children pool = 23
# lowest error = nan
# counter = 553
# children pool = 21
# lowest error = 0.0
# counter = 554
# children pool = 22
# lowest error = 0.0
# counter = 555
# children pool = 20
# lowest error = 0.0
# counter = 556
# children pool = 22
# lowest error = 0.0
# counter = 557
# children pool = 28
# lowest error = nan
# counter = 558
# children pool = 32
# lowest error = 0.03945029
# counter = 559
# children pool = 34
# lowest error = 0.03945029
# counter = 560
# children pool = 33
# lowest error = 0.0
# counter = 561
# children pool = 34
# lowest error = 0.0
# counter = 562
# children pool = 32
# lowest error = nan
# counter = 563
# children pool = 28
# lowest error = 0.0
# counter = 564
# children pool = 23
# lowest error = nan
# counter = 565
# children pool = 23
# lowest error = 0.0
# counter = 566
# children pool = 22
# lowest error = 0.0
# counter = 567
# children pool = 20
# lowest error = 0.0
# counter = 568
# children pool = 18
# lowest error = 0.0
# counter = 569
# children pool = 15
# lowest error = 0.0
# counter = 570
# children pool = 14
# lowest error = 0.0
# counter = 571
# children pool = 16
# lowest error = nan
# counter = 572
# children pool = 16
# lowest error = 0.0
# counter = 573
# children pool = 16
# lowest error = nan
# counter = 574
# children pool = 20
# lowest error = 0.0
# counter = 575
# children pool = 16
# lowest error = 0.0
# counter = 576
# children pool = 16
# lowest error = 0.0
# counter = 577
# children pool = 16
# lowest error = 0.0
# counter = 578
# children pool = 15
# lowest error = 0.0
# counter = 579
# children pool = 15
# lowest error = nan
# counter = 580
# children pool = 15
# lowest error = 0.0
# counter = 581
# children pool = 15
# lowest error = 0.0
# counter = 582
# children pool = 14
# lowest error = nan
# counter = 583
# children pool = 15
# lowest error = 0.0
# counter = 584
# children pool = 15
# lowest error = 0.0
# counter = 585
# children pool = 19
# lowest error = 0.0
# counter = 586
# children pool = 20
# lowest error = 0.0
# counter = 587
# children pool = 20
# lowest error = 0.0
# counter = 588
# children pool = 19
# lowest error = 0.0
# counter = 589
# children pool = 19
# lowest error = 0.0
# counter = 590
# children pool = 21
# lowest error = 0.0
# counter = 591
# children pool = 19
# lowest error = 0.0
# counter = 592
# children pool = 20
# lowest error = 0.0
# counter = 593
# children pool = 19
# lowest error = 0.0
# counter = 594
# children pool = 19
# lowest error = 0.0
# counter = 595
# children pool = 21
# lowest error = 0.0
# counter = 596
# children pool = 24
# lowest error = 0.0
# counter = 597
# children pool = 23
# lowest error = nan
# counter = 598
# children pool = 22
# lowest error = 0.0
# counter = 599
# children pool = 21
# lowest error = 0.0
# counter = 600
# children pool = 19
# lowest error = nan
# counter = 601
# children pool = 19
# lowest error = 0.0
# counter = 602
# children pool = 19
# lowest error = 0.0
# counter = 603
# children pool = 19
# lowest error = 0.0
# counter = 604
# children pool = 14
# lowest error = nan
# counter = 605
# children pool = 16
# lowest error = 0.0
# counter = 606
# children pool = 14
# lowest error = 0.0
# counter = 607
# children pool = 15
# lowest error = 0.0
# counter = 608
# children pool = 16
# lowest error = 0.0
# counter = 609
# children pool = 16
# lowest error = 0.0
# counter = 610
# children pool = 14
# lowest error = 0.0
# counter = 611
# children pool = 15
# lowest error = 0.0
# counter = 612
# children pool = 13
# lowest error = 0.0
# counter = 613
# children pool = 13
# lowest error = 0.0
# counter = 614
# children pool = 12
# lowest error = 0.0
# counter = 615
# children pool = 16
# lowest error = 0.0
# counter = 616
# children pool = 16
# lowest error = 0.0
# counter = 617
# children pool = 14
# lowest error = 0.0
# counter = 618
# children pool = 16
# lowest error = 0.0
# counter = 619
# children pool = 16
# lowest error = 0.0
# counter = 620
# children pool = 16
# lowest error = 0.0
# counter = 621
# children pool = 16
# lowest error = 0.0
# counter = 622
# children pool = 14
# lowest error = 0.0
# counter = 623
# children pool = 14
# lowest error = nan
# counter = 624
# children pool = 15
# lowest error = 0.0
# counter = 625
# children pool = 15
# lowest error = 0.0
# counter = 626
# children pool = 15
# lowest error = 0.0
# counter = 627
# children pool = 13
# lowest error = 0.0
# counter = 628
# children pool = 15
# lowest error = 0.0
# counter = 629
# children pool = 14
# lowest error = 0.0
# counter = 630
# children pool = 16
# lowest error = 0.0
# counter = 631
# children pool = 19
# lowest error = 0.0
# counter = 632
# children pool = 19
# lowest error = nan
# counter = 633
# children pool = 16
# lowest error = 0.0
# counter = 634
# children pool = 15
# lowest error = 0.0
# counter = 635
# children pool = 16
# lowest error = 0.0
# counter = 636
# children pool = 18
# lowest error = 0.0
# counter = 637
# children pool = 19
# lowest error = 0.0
# counter = 638
# children pool = 19
# lowest error = 0.0
# counter = 639
# children pool = 19
# lowest error = 0.0
# counter = 640
# children pool = 19
# lowest error = 0.0
# counter = 641
# children pool = 20
# lowest error = 0.0
# counter = 642
# children pool = 22
# lowest error = 0.0
# counter = 643
# children pool = 20
# lowest error = 0.0
# counter = 644
# children pool = 21
# lowest error = 0.0
# counter = 645
# children pool = 23
# lowest error = nan
# counter = 646
# children pool = 23
# lowest error = 0.0
# counter = 647
# children pool = 26
# lowest error = 0.00382635
# counter = 648
# children pool = 28
# lowest error = 3.92e-06
# counter = 649
# children pool = 24
# lowest error = 3.92e-06
# counter = 650
# children pool = 22
# lowest error = 3.92e-06
# counter = 651
# children pool = 24
# lowest error = 3.92e-06
# counter = 652
# children pool = 27
# lowest error = 0.00019938
# counter = 653
# children pool = 34
# lowest error = 0.04362398
# counter = 654
# children pool = 34
# lowest error = 0.04390653
# counter = 655
# children pool = 30
# lowest error = 0.04390653
# counter = 656
# children pool = 30
# lowest error = 1207.05348617
# counter = 657
# children pool = 30
# lowest error = 1207.05348617
# counter = 658
# children pool = 29
# lowest error = 1207.05348617
# counter = 659
# children pool = 30
# lowest error = 215.23900224
# counter = 660
# children pool = 29
# lowest error = 0.0
# counter = 661
# children pool = 30
# lowest error = 0.0
# counter = 662
# children pool = 34
# lowest error = 0.0
# counter = 663
# children pool = 39
# lowest error = nan
# counter = 664
# children pool = 44
# lowest error = 0.0
# counter = 665
# children pool = 50
# lowest error = 0.0
# counter = 666
# children pool = 60
# lowest error = 0.0
# counter = 667
# children pool = 64
# lowest error = 3.12092408
# counter = 668
# children pool = 64
# lowest error = 5.8e-06
# counter = 669
# children pool = 60
# lowest error = nan
# counter = 670
# children pool = 54
# lowest error = 5.8e-06
# counter = 671
# children pool = 49
# lowest error = 668.86656494
# counter = 672
# children pool = 44
# lowest error = 216.66666667
# counter = 673
# children pool = 40
# lowest error = 1.86453669
# counter = 674
# children pool = 30
# lowest error = 1.86453669
# counter = 675
# children pool = 30
# lowest error = 0.0
# counter = 676
# children pool = 33
# lowest error = 0.0
# counter = 677
# children pool = 34
# lowest error = 0.0
# counter = 678
# children pool = 29
# lowest error = 0.0
# counter = 679
# children pool = 29
# lowest error = 1.11051091
# counter = 680
# children pool = 30
# lowest error = 0.51529225
# counter = 681
# children pool = 29
# lowest error = 0.00058796
# counter = 682
# children pool = 28
# lowest error = 0.00058796
# counter = 683
# children pool = 22
# lowest error = 0.00058796
# counter = 684
# children pool = 17
# lowest error = 0.00058796
# counter = 685
# children pool = 14
# lowest error = 0.00058796
# counter = 686
# children pool = 15
# lowest error = 0.00058796
# counter = 687
# children pool = 14
# lowest error = 0.00058796
# counter = 688
# children pool = 14
# lowest error = 0.00058796
# counter = 689
# children pool = 14
# lowest error = 0.00058796
# counter = 690
# children pool = 13
# lowest error = 0.0
# counter = 691
# children pool = 16
# lowest error = 0.0
# counter = 692
# children pool = 14
# lowest error = 0.0
# counter = 693
# children pool = 14
# lowest error = 0.0
# counter = 694
# children pool = 14
# lowest error = 0.0
# counter = 695
# children pool = 14
# lowest error = 0.0
# counter = 696
# children pool = 13
# lowest error = 0.0
# counter = 697
# children pool = 13
# lowest error = 0.0
# counter = 698
# children pool = 12
# lowest error = 0.0
# counter = 699
# children pool = 16
# lowest error = 0.0
# counter = 700
# children pool = 16
# lowest error = 0.0
# counter = 701
# children pool = 14
# lowest error = 0.0
# counter = 702
# children pool = 13
# lowest error = 0.0
# counter = 703
# children pool = 13
# lowest error = 0.0
# counter = 704
# children pool = 14
# lowest error = 0.0
# counter = 705
# children pool = 15
# lowest error = 0.0
# counter = 706
# children pool = 14
# lowest error = 0.0
# counter = 707
# children pool = 13
# lowest error = 0.0
# counter = 708
# children pool = 15
# lowest error = 0.0
# counter = 709
# children pool = 16
# lowest error = 0.11236897
# counter = 710
# children pool = 16
# lowest error = 0.11236897
# counter = 711
# children pool = 16
# lowest error = 0.00058796
# counter = 712
# children pool = 14
# lowest error = 0.0
# counter = 713
# children pool = 13
# lowest error = 0.0
# counter = 714
# children pool = 15
# lowest error = 0.0
# counter = 715
# children pool = 15
# lowest error = 0.0
# counter = 716
# children pool = 15
# lowest error = 0.0
# counter = 717
# children pool = 14
# lowest error = 0.0
# counter = 718
# children pool = 14
# lowest error = 0.0
# counter = 719
# children pool = 12
# lowest error = 0.0
# counter = 720
# children pool = 15
# lowest error = 0.0
# counter = 721
# children pool = 15
# lowest error = 0.0
# counter = 722
# children pool = 16
# lowest error = 0.0
# counter = 723
# children pool = 13
# lowest error = 0.0
# counter = 724
# children pool = 16
# lowest error = 0.0
# counter = 725
# children pool = 20
# lowest error = 0.0
# counter = 726
# children pool = 14
# lowest error = 0.0
# counter = 727
# children pool = 16
# lowest error = 0.0
# counter = 728
# children pool = 13
# lowest error = 0.0
# counter = 729
# children pool = 14
# lowest error = 0.0
# counter = 730
# children pool = 14
# lowest error = nan
# counter = 731
# children pool = 14
# lowest error = 0.0
# counter = 732
# children pool = 13
# lowest error = 0.0
# counter = 733
# children pool = 16
# lowest error = nan
# counter = 734
# children pool = 13
# lowest error = 0.0
# counter = 735
# children pool = 14
# lowest error = 0.0
# counter = 736
# children pool = 15
# lowest error = 0.0
# counter = 737
# children pool = 13
# lowest error = 0.0
# counter = 738
# children pool = 14
# lowest error = 0.0
# counter = 739
# children pool = 15
# lowest error = nan
# counter = 740
# children pool = 15
# lowest error = 0.0
# counter = 741
# children pool = 12
# lowest error = 0.0
# counter = 742
# children pool = 16
# lowest error = 0.0
# counter = 743
# children pool = 14
# lowest error = 0.0
# counter = 744
# children pool = 14
# lowest error = 0.0
# counter = 745
# children pool = 14
# lowest error = 0.0
# counter = 746
# children pool = 14
# lowest error = 0.0
# counter = 747
# children pool = 16
# lowest error = 0.0
# counter = 748
# children pool = 12
# lowest error = 0.0
# counter = 749
# children pool = 14
# lowest error = 0.0
# counter = 750
# children pool = 12
# lowest error = 0.0
# counter = 751
# children pool = 13
# lowest error = 0.0
# counter = 752
# children pool = 15
# lowest error = 0.0
# counter = 753
# children pool = 14
# lowest error = 0.0
# counter = 754
# children pool = 15
# lowest error = 0.0
# counter = 755
# children pool = 14
# lowest error = 0.0
# counter = 756
# children pool = 12
# lowest error = 0.0
# counter = 757
# children pool = 15
# lowest error = 0.0
# counter = 758
# children pool = 14
# lowest error = 0.0
# counter = 759
# children pool = 15
# lowest error = 0.0
# counter = 760
# children pool = 16
# lowest error = 0.0
# counter = 761
# children pool = 16
# lowest error = 0.0
# counter = 762
# children pool = 15
# lowest error = 0.0
# counter = 763
# children pool = 15
# lowest error = 0.0
# counter = 764
# children pool = 14
# lowest error = 0.0
# counter = 765
# children pool = 16
# lowest error = 7.729e-05
# counter = 766
# children pool = 15
# lowest error = 7.729e-05
# counter = 767
# children pool = 15
# lowest error = 7.729e-05
# counter = 768
# children pool = 15
# lowest error = 7.729e-05
# counter = 769
# children pool = 12
# lowest error = 7.729e-05
# counter = 770
# children pool = 14
# lowest error = 7.729e-05
# counter = 771
# children pool = 12
# lowest error = 0.0
# counter = 772
# children pool = 12
# lowest error = 0.0
# counter = 773
# children pool = 14
# lowest error = 0.0
# counter = 774
# children pool = 14
# lowest error = 0.0
# counter = 775
# children pool = 16
# lowest error = 0.0
# counter = 776
# children pool = 16
# lowest error = 0.0
# counter = 777
# children pool = 15
# lowest error = 0.0
# counter = 778
# children pool = 15
# lowest error = 0.0
# counter = 779
# children pool = 16
# lowest error = 0.0
# counter = 780
# children pool = 14
# lowest error = 0.0
# counter = 781
# children pool = 15
# lowest error = 0.0
# counter = 782
# children pool = 15
# lowest error = 0.0
# counter = 783
# children pool = 15
# lowest error = 0.0
# counter = 784
# children pool = 16
# lowest error = 0.0
# counter = 785
# children pool = 12
# lowest error = 0.0
# counter = 786
# children pool = 12
# lowest error = 0.0
# counter = 787
# children pool = 15
# lowest error = 0.0
# counter = 788
# children pool = 14
# lowest error = 0.0
# counter = 789
# children pool = 16
# lowest error = 0.0
# counter = 790
# children pool = 15
# lowest error = 0.0
# counter = 791
# children pool = 14
# lowest error = 0.0
# counter = 792
# children pool = 14
# lowest error = 0.0
# counter = 793
# children pool = 16
# lowest error = 0.0
# counter = 794
# children pool = 16
# lowest error = 0.0
# counter = 795
# children pool = 13
# lowest error = 0.0
# counter = 796
# children pool = 14
# lowest error = 0.0
# counter = 797
# children pool = 15
# lowest error = 0.0
# counter = 798
# children pool = 15
# lowest error = 0.0
# counter = 799
# children pool = 16
# lowest error = 0.0
# counter = 800
# children pool = 14
# lowest error = 0.0
# counter = 801
# children pool = 16
# lowest error = 0.0
# counter = 802
# children pool = 15
# lowest error = 0.0
# counter = 803
# children pool = 14
# lowest error = 0.0
# counter = 804
# children pool = 16
# lowest error = 0.0
# counter = 805
# children pool = 15
# lowest error = 0.0
# counter = 806
# children pool = 15
# lowest error = 0.0
# counter = 807
# children pool = 14
# lowest error = 0.0
# counter = 808
# children pool = 15
# lowest error = 0.0
# counter = 809
# children pool = 16
# lowest error = 0.0
# counter = 810
# children pool = 15
# lowest error = 0.0
# counter = 811
# children pool = 16
# lowest error = 0.0
# counter = 812
# children pool = 16
# lowest error = 0.0
# counter = 813
# children pool = 15
# lowest error = nan
# counter = 814
# children pool = 16
# lowest error = 0.0
# counter = 815
# children pool = 16
# lowest error = 0.0
# counter = 816
# children pool = 19
# lowest error = 0.0
# counter = 817
# children pool = 16
# lowest error = 0.0
# counter = 818
# children pool = 15
# lowest error = 0.0
# counter = 819
# children pool = 15
# lowest error = 0.0
# counter = 820
# children pool = 16
# lowest error = 0.0
# counter = 821
# children pool = 15
# lowest error = 0.0
# counter = 822
# children pool = 16
# lowest error = 0.0
# counter = 823
# children pool = 13
# lowest error = 0.0
# counter = 824
# children pool = 13
# lowest error = 0.0
# counter = 825
# children pool = 14
# lowest error = 0.0
# counter = 826
# children pool = 16
# lowest error = 0.0
# counter = 827
# children pool = 15
# lowest error = 0.0
# counter = 828
# children pool = 13
# lowest error = 0.0
# counter = 829
# children pool = 15
# lowest error = 0.0
# counter = 830
# children pool = 19
# lowest error = 0.0
# counter = 831
# children pool = 16
# lowest error = 0.0
# counter = 832
# children pool = 19
# lowest error = 0.0
# counter = 833
# children pool = 19
# lowest error = 0.0
# counter = 834
# children pool = 15
# lowest error = 0.0
# counter = 835
# children pool = 16
# lowest error = 0.0
# counter = 836
# children pool = 14
# lowest error = 0.0
# counter = 837
# children pool = 16
# lowest error = 0.0
# counter = 838
# children pool = 16
# lowest error = 0.0
# counter = 839
# children pool = 16
# lowest error = 0.0
# counter = 840
# children pool = 16
# lowest error = 0.0
# counter = 841
# children pool = 16
# lowest error = nan
# counter = 842
# children pool = 14
# lowest error = 0.0
# counter = 843
# children pool = 20
# lowest error = nan
# counter = 844
# children pool = 18
# lowest error = 0.0
# counter = 845
# children pool = 20
# lowest error = 0.0
# counter = 846
# children pool = 17
# lowest error = 0.0
# counter = 847
# children pool = 17
# lowest error = 0.0
# counter = 848
# children pool = 19
# lowest error = 0.0
# counter = 849
# children pool = 17
# lowest error = 0.0
# counter = 850
# children pool = 16
# lowest error = 0.0
# counter = 851
# children pool = 15
# lowest error = 0.0
# counter = 852
# children pool = 14
# lowest error = 0.0
# counter = 853
# children pool = 14
# lowest error = 0.0
# counter = 854
# children pool = 15
# lowest error = 0.0
# counter = 855
# children pool = 16
# lowest error = 0.0
# counter = 856
# children pool = 18
# lowest error = 0.0
# counter = 857
# children pool = 19
# lowest error = 0.0
# counter = 858
# children pool = 14
# lowest error = nan
# counter = 859
# children pool = 16
# lowest error = 0.0
# counter = 860
# children pool = 16
# lowest error = 0.0
# counter = 861
# children pool = 16
# lowest error = 0.0
# counter = 862
# children pool = 16
# lowest error = 0.0
# counter = 863
# children pool = 16
# lowest error = 0.0
# counter = 864
# children pool = 15
# lowest error = 0.0
# counter = 865
# children pool = 16
# lowest error = 0.0
# counter = 866
# children pool = 16
# lowest error = 0.0
# counter = 867
# children pool = 15
# lowest error = 0.0
# counter = 868
# children pool = 15
# lowest error = nan
# counter = 869
# children pool = 16
# lowest error = 0.0
# counter = 870
# children pool = 16
# lowest error = 0.0
# counter = 871
# children pool = 15
# lowest error = 0.0
# counter = 872
# children pool = 15
# lowest error = nan
# counter = 873
# children pool = 13
# lowest error = 0.0
# counter = 874
# children pool = 13
# lowest error = 0.0
# counter = 875
# children pool = 15
# lowest error = 0.0
# counter = 876
# children pool = 17
# lowest error = nan
# counter = 877
# children pool = 16
# lowest error = 0.0
# counter = 878
# children pool = 15
# lowest error = 0.0
# counter = 879
# children pool = 16
# lowest error = 0.0
# counter = 880
# children pool = 15
# lowest error = 0.0
# counter = 881
# children pool = 15
# lowest error = 0.0
# counter = 882
# children pool = 16
# lowest error = 0.0
# counter = 883
# children pool = 16
# lowest error = nan
# counter = 884
# children pool = 16
# lowest error = nan
# counter = 885
# children pool = 17
# lowest error = 0.0
# counter = 886
# children pool = 17
# lowest error = 0.0
# counter = 887
# children pool = 20
# lowest error = 0.0
# counter = 888
# children pool = 20
# lowest error = 0.0
# counter = 889
# children pool = 17
# lowest error = 0.0
# counter = 890
# children pool = 16
# lowest error = 0.0
# counter = 891
# children pool = 19
# lowest error = 0.0
# counter = 892
# children pool = 17
# lowest error = 0.0
# counter = 893
# children pool = 15
# lowest error = nan
# counter = 894
# ...
# counter = 19681
# children pool = 15
# lowest error = nan
# counter = 19682
# children pool = 16
# lowest error = nan
# counter = 19683
# children pool = 15
# lowest error = 0.0
# counter = 19684
# children pool = 13
# lowest error = 0.0
# counter = 19685
# children pool = 12
# lowest error = 0.0
# counter = 19686
# children pool = 13
# lowest error = 0.0
# counter = 19687
# children pool = 14
# lowest error = nan
# counter = 19688
# children pool = 14
# lowest error = 0.0
# counter = 19689
# children pool = 14
# lowest error = 0.0
# counter = 19690
# children pool = 13
# lowest error = 0.0
# counter = 19691
# children pool = 13
# lowest error = 0.0
# counter = 19692
# children pool = 12
# lowest error = 0.0
# counter = 19693
# children pool = 16
# lowest error = 0.0
# counter = 19694
# children pool = 15
# lowest error = 0.0
# counter = 19695
# children pool = 16
# lowest error = nan
# counter = 19696
# children pool = 15
# lowest error = nan
# counter = 19697
# children pool = 15
# lowest error = 0.0
# counter = 19698
# children pool = 13
# lowest error = 0.0
# counter = 19699
# children pool = 14
# lowest error = 0.0
# counter = 19700
# children pool = 16
# lowest error = 0.0
# counter = 19701
# children pool = 12
# lowest error = 0.0
# counter = 19702
# children pool = 14
# lowest error = 0.0
# counter = 19703
# children pool = 14
# lowest error = 0.0
# counter = 19704
# children pool = 13
# lowest error = 0.0
# counter = 19705
# children pool = 15
# lowest error = 0.0
# counter = 19706
# children pool = 16
# lowest error = 0.0
# counter = 19707
# children pool = 14
# lowest error = 0.0
# counter = 19708
# children pool = 15
# lowest error = 0.0
# counter = 19709
# children pool = 14
# lowest error = 0.0
# counter = 19710
# children pool = 14
# lowest error = 0.0
# counter = 19711
# children pool = 14
# lowest error = 0.0
# counter = 19712
# children pool = 16
# lowest error = 0.0
# counter = 19713
# children pool = 13
# lowest error = 0.0
# counter = 19714
# children pool = 15
# lowest error = 0.0
# counter = 19715
# children pool = 16
# lowest error = 0.0
# counter = 19716
# children pool = 16
# lowest error = 0.0
# counter = 19717
# children pool = 14
# lowest error = 0.0
# counter = 19718
# children pool = 15
# lowest error = 0.0
# counter = 19719
# children pool = 14
# lowest error = 0.0
# counter = 19720
# children pool = 16
# lowest error = 0.0
# counter = 19721
# children pool = 16
# lowest error = 0.0
# counter = 19722
# children pool = 14
# lowest error = 0.0
# counter = 19723
# children pool = 14
# lowest error = 0.0
# counter = 19724
# children pool = 15
# lowest error = 0.0
# counter = 19725
# children pool = 16
# lowest error = 0.0
# counter = 19726
# children pool = 14
# lowest error = 0.0
# counter = 19727
# children pool = 16
# lowest error = 0.0
# counter = 19728
# children pool = 14
# lowest error = 0.0
# counter = 19729
# children pool = 16
# lowest error = nan
# counter = 19730
# children pool = 14
# lowest error = 0.0
# counter = 19731
# children pool = 14
# lowest error = 0.0
# counter = 19732
# children pool = 15
# lowest error = 0.0
# counter = 19733
# children pool = 16
# lowest error = 0.0
# counter = 19734
# children pool = 15
# lowest error = 0.0
# counter = 19735
# children pool = 14
# lowest error = 0.0
# counter = 19736
# children pool = 16
# lowest error = 0.0
# counter = 19737
# children pool = 13
# lowest error = nan
# counter = 19738
# children pool = 15
# lowest error = 0.0
# counter = 19739
# children pool = 16
# lowest error = 0.0
# counter = 19740
# children pool = 16
# lowest error = 0.0
# counter = 19741
# children pool = 16
# lowest error = 0.0
# counter = 19742
# children pool = 14
# lowest error = 0.0
# counter = 19743
# children pool = 15
# lowest error = 0.0
# counter = 19744
# children pool = 16
# lowest error = 0.0
# counter = 19745
# children pool = 16
# lowest error = 0.0
# counter = 19746
# children pool = 12
# lowest error = 0.0
# counter = 19747
# children pool = 13
# lowest error = 0.0
# counter = 19748
# children pool = 16
# lowest error = 0.0
# counter = 19749
# children pool = 16
# lowest error = 0.0
# counter = 19750
# children pool = 14
# lowest error = 0.0
# counter = 19751
# children pool = 16
# lowest error = 0.0
# counter = 19752
# children pool = 16
# lowest error = 0.0
# counter = 19753
# children pool = 16
# lowest error = 0.0
# counter = 19754
# children pool = 16
# lowest error = 0.0
# counter = 19755
# children pool = 16
# lowest error = 0.0
# counter = 19756
# children pool = 16
# lowest error = 0.0
# counter = 19757
# children pool = 16
# lowest error = 0.0
# counter = 19758
# children pool = 20
# lowest error = 0.0
# counter = 19759
# children pool = 16
# lowest error = 0.0
# counter = 19760
# children pool = 15
# lowest error = 0.0
# counter = 19761
# children pool = 15
# lowest error = nan
# counter = 19762
# children pool = 15
# lowest error = nan
# counter = 19763
# children pool = 16
# lowest error = 1.095e-05
# counter = 19764
# children pool = 16
# lowest error = 1.095e-05
# counter = 19765
# children pool = 17
# lowest error = 1.095e-05
# counter = 19766
# children pool = 16
# lowest error = 1.095e-05
# counter = 19767
# children pool = 15
# lowest error = 1.095e-05
# counter = 19768
# children pool = 14
# lowest error = 1.095e-05
# counter = 19769
# children pool = 14
# lowest error = 1.095e-05
# counter = 19770
# children pool = 16
# lowest error = 1.095e-05
# counter = 19771
# children pool = 16
# lowest error = 1.095e-05
# counter = 19772
# children pool = 16
# lowest error = 1.095e-05
# counter = 19773
# children pool = 15
# lowest error = 1.095e-05
# counter = 19774
# children pool = 16
# lowest error = 1.095e-05
# counter = 19775
# children pool = 16
# lowest error = 1.095e-05
# counter = 19776
# children pool = 15
# lowest error = 1.095e-05
# counter = 19777
# children pool = 14
# lowest error = 1.095e-05
# counter = 19778
# children pool = 16
# lowest error = 1.095e-05
# counter = 19779
# children pool = 15
# lowest error = 1.095e-05
# counter = 19780
# children pool = 15
# lowest error = 1.095e-05
# counter = 19781
# children pool = 16
# lowest error = 1.095e-05
# counter = 19782
# children pool = 14
# lowest error = 1.095e-05
# counter = 19783
# children pool = 16
# lowest error = 1.095e-05
# counter = 19784
# children pool = 15
# lowest error = 1.095e-05
# counter = 19785
# children pool = 15
# lowest error = 1.095e-05
# counter = 19786
# children pool = 18
# lowest error = 1.095e-05
# counter = 19787
# children pool = 18
# lowest error = 1.095e-05
# counter = 19788
# children pool = 18
# lowest error = 1.095e-05
# counter = 19789
# children pool = 16
# lowest error = 1.095e-05
# counter = 19790
# children pool = 16
# lowest error = nan
# counter = 19791
# children pool = 16
# lowest error = 0.0
# counter = 19792
# children pool = 15
# lowest error = 0.0
# counter = 19793
# children pool = 16
# lowest error = nan
# counter = 19794
# children pool = 15
# lowest error = nan
# counter = 19795
# children pool = 18
# lowest error = nan
# counter = 19796
# children pool = 19
# lowest error = 0.0
# counter = 19797
# children pool = 16
# lowest error = 0.0
# counter = 19798
# children pool = 19
# lowest error = 0.0
# counter = 19799
# children pool = 15
# lowest error = 0.0
# counter = 19800
# children pool = 15
# lowest error = 0.0
# counter = 19801
# children pool = 15
# lowest error = 0.0
# counter = 19802
# children pool = 16
# lowest error = 0.0
# counter = 19803
# children pool = 19
# lowest error = 0.0
# counter = 19804
# children pool = 20
# lowest error = 0.0
# counter = 19805
# children pool = 19
# lowest error = 0.0
# counter = 19806
# children pool = 15
# lowest error = 0.0
# counter = 19807
# children pool = 16
# lowest error = 0.0
# counter = 19808
# children pool = 16
# lowest error = nan
# counter = 19809
# children pool = 16
# lowest error = 0.0
# counter = 19810
# children pool = 15
# lowest error = 0.0
# counter = 19811
# children pool = 16
# lowest error = 0.0
# counter = 19812
# children pool = 16
# lowest error = 0.0
# counter = 19813
# children pool = 14
# lowest error = 0.0
# counter = 19814
# children pool = 16
# lowest error = 0.0
# counter = 19815
# children pool = 16
# lowest error = 0.0
# counter = 19816
# children pool = 15
# lowest error = 0.0
# counter = 19817
# children pool = 16
# lowest error = 0.0
# counter = 19818
# children pool = 16
# lowest error = 0.0
# counter = 19819
# children pool = 15
# lowest error = 0.0
# counter = 19820
# children pool = 16
# lowest error = 0.0
# counter = 19821
# children pool = 16
# lowest error = 0.0
# counter = 19822
# children pool = 17
# lowest error = 0.0
# counter = 19823
# children pool = 17
# lowest error = 0.0
# counter = 19824
# children pool = 19
# lowest error = 0.0
# counter = 19825
# children pool = 14
# lowest error = 0.0
# counter = 19826
# children pool = 15
# lowest error = 0.0
# counter = 19827
# children pool = 16
# lowest error = 0.0
# counter = 19828
# children pool = 16
# lowest error = 0.0
# counter = 19829
# children pool = 16
# lowest error = 0.0
# counter = 19830
# children pool = 15
# lowest error = 0.0
# counter = 19831
# children pool = 19
# lowest error = 0.0
# counter = 19832
# children pool = 15
# lowest error = 0.0
# counter = 19833
# children pool = 15
# lowest error = 0.0
# counter = 19834
# children pool = 14
# lowest error = 0.0
# counter = 19835
# children pool = 14
# lowest error = 0.0
# counter = 19836
# children pool = 15
# lowest error = 0.0
# counter = 19837
# children pool = 16
# lowest error = 0.0
# counter = 19838
# children pool = 14
# lowest error = 0.0
# counter = 19839
# children pool = 16
# lowest error = 0.0
# counter = 19840
# children pool = 16
# lowest error = 0.0
# counter = 19841
# children pool = 16
# lowest error = 0.0
# counter = 19842
# children pool = 14
# lowest error = 0.0
# counter = 19843
# children pool = 12
# lowest error = 0.0
# counter = 19844
# children pool = 14
# lowest error = 0.0
# counter = 19845
# children pool = 15
# lowest error = 0.0
# counter = 19846
# children pool = 15
# lowest error = 0.0
# counter = 19847
# children pool = 15
# lowest error = 0.0
# counter = 19848
# children pool = 15
# lowest error = 0.0
# counter = 19849
# children pool = 15
# lowest error = 0.0
# counter = 19850
# children pool = 14
# lowest error = 0.0
# counter = 19851
# children pool = 15
# lowest error = 0.0
# counter = 19852
# children pool = 16
# lowest error = 0.0
# counter = 19853
# children pool = 16
# lowest error = 0.0
# counter = 19854
# children pool = 16
# lowest error = 0.0
# counter = 19855
# children pool = 16
# lowest error = 0.0
# counter = 19856
# children pool = 18
# lowest error = 0.0
# counter = 19857
# children pool = 19
# lowest error = 0.0
# counter = 19858
# children pool = 19
# lowest error = 0.0
# counter = 19859
# children pool = 14
# lowest error = 0.0
# counter = 19860
# children pool = 16
# lowest error = 0.0
# counter = 19861
# children pool = 13
# lowest error = 0.0
# counter = 19862
# children pool = 14
# lowest error = 0.0
# counter = 19863
# children pool = 15
# lowest error = 0.0
# counter = 19864
# children pool = 16
# lowest error = 0.0
# counter = 19865
# children pool = 15
# lowest error = 0.0
# counter = 19866
# children pool = 15
# lowest error = 0.0
# counter = 19867
# children pool = 16
# lowest error = 0.0
# counter = 19868
# children pool = 17
# lowest error = 0.0
# counter = 19869
# children pool = 16
# lowest error = 0.0
# counter = 19870
# children pool = 15
# lowest error = 0.0
# counter = 19871
# children pool = 15
# lowest error = 0.0
# counter = 19872
# children pool = 16
# lowest error = 0.0
# counter = 19873
# children pool = 14
# lowest error = 0.0
# counter = 19874
# children pool = 16
# lowest error = 0.0
# counter = 19875
# children pool = 19
# lowest error = 0.0
# counter = 19876
# children pool = 19
# lowest error = 0.0
# counter = 19877
# children pool = 16
# lowest error = 0.0
# counter = 19878
# children pool = 14
# lowest error = 0.0
# counter = 19879
# children pool = 16
# lowest error = 0.0
# counter = 19880
# children pool = 16
# lowest error = 0.0
# counter = 19881
# children pool = 19
# lowest error = 0.0
# counter = 19882
# children pool = 15
# lowest error = 0.0
# counter = 19883
# children pool = 19
# lowest error = 0.0
# counter = 19884
# children pool = 20
# lowest error = 0.0
# counter = 19885
# children pool = 15
# lowest error = 0.0
# counter = 19886
# children pool = 16
# lowest error = 0.0
# counter = 19887
# children pool = 16
# lowest error = 0.0
# counter = 19888
# children pool = 16
# lowest error = 0.0
# counter = 19889
# children pool = 19
# lowest error = 0.0
# counter = 19890
# children pool = 17
# lowest error = 0.0
# counter = 19891
# children pool = 19
# lowest error = 0.0
# counter = 19892
# children pool = 19
# lowest error = 0.0
# counter = 19893
# children pool = 18
# lowest error = 0.0
# counter = 19894
# children pool = 19
# lowest error = 0.0
# counter = 19895
# children pool = 19
# lowest error = nan
# counter = 19896
# children pool = 18
# lowest error = 0.0
# counter = 19897
# children pool = 15
# lowest error = 0.0
# counter = 19898
# children pool = 19
# lowest error = 0.0
# counter = 19899
# children pool = 18
# lowest error = 0.0
# counter = 19900
# children pool = 19
# lowest error = 0.0
# counter = 19901
# children pool = 18
# lowest error = 0.0
# counter = 19902
# children pool = 19
# lowest error = 0.0
# counter = 19903
# children pool = 14
# lowest error = 0.0
# counter = 19904
# children pool = 15
# lowest error = 0.0
# counter = 19905
# children pool = 15
# lowest error = 0.0
# counter = 19906
# children pool = 16
# lowest error = 0.0
# counter = 19907
# children pool = 16
# lowest error = nan
# counter = 19908
# children pool = 15
# lowest error = 0.0
# counter = 19909
# children pool = 15
# lowest error = 0.0
# counter = 19910
# children pool = 16
# lowest error = 0.0
# counter = 19911
# children pool = 15
# lowest error = 0.0
# counter = 19912
# children pool = 15
# lowest error = nan
# counter = 19913
# children pool = 15
# lowest error = 0.0
# counter = 19914
# children pool = 16
# lowest error = 0.0
# counter = 19915
# children pool = 15
# lowest error = 0.0
# counter = 19916
# children pool = 15
# lowest error = 0.0
# counter = 19917
# children pool = 15
# lowest error = 0.0
# counter = 19918
# children pool = 16
# lowest error = 0.0
# counter = 19919
# children pool = 16
# lowest error = 0.0
# counter = 19920
# children pool = 14
# lowest error = 0.0
# counter = 19921
# children pool = 16
# lowest error = 0.0
# counter = 19922
# children pool = 16
# lowest error = 0.0
# counter = 19923
# children pool = 16
# lowest error = 0.0
# counter = 19924
# children pool = 16
# lowest error = 0.0
# counter = 19925
# children pool = 16
# lowest error = 0.0
# counter = 19926
# children pool = 15
# lowest error = 0.0
# counter = 19927
# children pool = 16
# lowest error = 0.0
# counter = 19928
# children pool = 14
# lowest error = 0.0
# counter = 19929
# children pool = 15
# lowest error = 0.0
# counter = 19930
# children pool = 15
# lowest error = 0.0
# counter = 19931
# children pool = 16
# lowest error = 0.0
# counter = 19932
# children pool = 16
# lowest error = 0.0
# counter = 19933
# children pool = 20
# lowest error = 0.0
# counter = 19934
# children pool = 24
# lowest error = 0.0
# counter = 19935
# children pool = 22
# lowest error = 0.0
# counter = 19936
# children pool = 22
# lowest error = 0.0
# counter = 19937
# children pool = 20
# lowest error = 0.0
# counter = 19938
# children pool = 20
# lowest error = 0.0
# counter = 19939
# children pool = 18
# lowest error = 0.0
# counter = 19940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-3a23bbfef54c> in <module>
# ----> 1 res_ea_div_mut = evol_algo_div_mut(num_eval=num_evaluation, x_s=x_s, y_s=y_s, depth=depth, init_pop=20, mutate_rate=0.5)
#
# <ipython-input-32-981ddcf94ab6> in evol_algo_div_mut(num_eval, x_s, y_s, depth, init_pop, mutate_rate)
#      27
#      28                 y_hat_kid1 = calculate_y(x_s=x_s, equation=kid1)
# ---> 29                 y_hat_kid2 = calculate_y(x_s=x_s, equation=kid2)
#      30
#      31                 children_pool[calc_mse(y=y_s, y_hat=y_hat_kid1)] = kid1
#
# <ipython-input-12-6c2896558c6a> in calculate_y(x_s, equation)
#       2     calculated_y = []
#       3     for ele in x_s:
# ----> 4         res = evaluate_binary_heap(equation, x=ele)
#       5         calculated_y.append(res)
#       6     return calculated_y
#
# <ipython-input-11-f83ed01f3e61> in evaluate_binary_heap(binary_heap, x)
#       6     """
#       7
# ----> 8     bh = copy.deepcopy(binary_heap)
#       9     for i in range(len(bh)-1, 0, -1):
#      10         try:
#
# /opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /opt/anaconda3/lib/python3.8/copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# /opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     126 del d, t
#     127
# --> 128 def deepcopy(x, memo=None, _nil=[]):
#     129     """Deep copy operation on arbitrary Python objects.
#     130
#
# KeyboardInterrupt:

# %%
res_ea_div_mut
# Out:
# [[0],
#  [nan],
#  ['nah',
#   '*',
#   '*',
#   '-',
#   '-',
#   '*',
#   'sin',
#   '/',
#   '-',
#   '-',
#   'x',
#   '+',
#   '-',
#   '+',
#   '/',
#   'sin',
#   '/',
#   9.0723,
#   '+',
#   '/',
#   '+',
#   'cos',
#   '/',
#   'x',
#   'sin',
#   '+',
#   '-',
#   'x',
#   '*',
#   4.8998,
#   'sin',
#   '-',
#   'cos',
#   'x',
#   'sin',
#   'cos',
#   7.4782,
#   'cos',
#   'x',
#   'x',
#   '*',
#   '/',
#   '-',
#   'cos',
#   'x',
#   'x',
#   'sin',
#   'sin',
#   '/',
#   'sin',
#   '-',
#   'sin',
#   'cos',
#   4.151,
#   'x',
#   '+',
#   '+',
#   'cos',
#   '+',
#   '+',
#   'cos',
#   'cos',
#   '+',
#   'x',
#   'cos',
#   'cos',
#   '*',
#   'sin',
#   '+',
#   'x',
#   'x',
#   '/',
#   5.4568,
#   '/',
#   'sin',
#   'sin',
#   '+',
#   '+',
#   '/',
#   'sin',
#   '-',
#   5.3238,
#   2.9902,
#   'x',
#   9.0988,
#   'x',
#   4.4332,
#   'x',
#   'x',
#   2.7928,
#   'x',
#   5.271,
#   9.3402,
#   9.6991,
#   'x',
#   8.083,
#   'x',
#   'x',
#   2.8312,
#   'x',
#   7.4247,
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   2.4645,
#   'x',
#   'x',
#   'x',
#   9.2958,
#   'x',
#   2.0378,
#   'x',
#   'x',
#   'x',
#   'x',
#   3.9602,
#   9.2865,
#   4.0094,
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   0.1925,
#   2.8025,
#   'x',
#   3.5885,
#   'x',
#   'x',
#   3.3739,
#   2.5617,
#   'x',
#   'x',
#   'x',
#   'x',
#   3.0942,
#   4.9543,
#   'x',
#   3.9335,
#   4.6394,
#   0.2442,
#   3.062,
#   'x',
#   'x',
#   7.8783,
#   'x',
#   4.0922,
#   2.8977,
#   7.6552,
#   'x',
#   'x',
#   9.5155,
#   4.4865,
#   7.6831,
#   'x',
#   1.3975,
#   3.1262,
#   'x',
#   3.4801,
#   6.4229,
#   4.3155],
#  [-59246.489992645926,
#   -41863.21856732799,
#   -45395.08840564023,
#   -44233.00497789642,
#   -22274.151505541082,
#   -20684.488667118818,
#   -24477.30933784129,
#   -17668.961386091294,
#   -16220.039802498513,
#   -17911.03160255956,
#   -7886.970215827717,
#   -5238.374079337367,
#   -6582.193115901209,
#   -4906.815698530998,
#   -3724.2819369832687,
#   -4450.389946696483,
#   -1560.4480991481453,
#   -335.61173911585126,
#   -590.863505425382,
#   -383.97304845119464,
#   -210.49707455995522,
#   -276.687853924841,
#   -28.029667052277524,
#   32.97820254753676,
#   -0.0,
#   nan,
#   25.24711275618612,
#   15.181455181613837,
#   161.25482476870923,
#   764.521018735037,
#   984.4150840487059,
#   1692.584216969593,
#   2216.2857537535783,
#   1896.3017193612036,
#   2924.4616090265367,
#   6783.828731998931,
#   7229.162327513904,
#   9902.512307648847,
#   12582.349258048072,
#   10606.085507113885,
#   12361.968461702701,
#   22886.854777413853,
#   24145.925001813786,
#   28207.02554121886,
#   37769.002902223954,
#   32565.49100910661,
#   32347.246809518834,
#   52688.0814233573,
#   58909.95670649389,
#   59399.524800356376,
#   82285.88423910322]]

# %%
res_ea_div = evol_algo_div(num_eval=num_evaluation, x_s=x_s, y_s=y_s, depth=depth, init_pop=50)
res_ea_div
# Out:
# <ipython-input-545-f83ed01f3e61>:28: RuntimeWarning: divide by zero encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]
# <ipython-input-545-f83ed01f3e61>:36: RuntimeWarning: invalid value encountered in cos
#   bh[i] = np.cos(bh[2*i])
# pool = 39
# children pool = 38
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 9.84212633
# counter = 1
# children pool = 36
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 9.84212633
# counter = 2
# children pool = 34
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 9.84212633
# counter = 3
# children pool = 34
# merged pool = 37
# # of keys = 15
# top pool = 31
# lowest error = 9.84212633
# counter = 4
# children pool = 30
# merged pool = 37
# # of keys = 15
# top pool = 32
# lowest error = 9.84212633
# counter = 5
# children pool = 31
# merged pool = 35
# # of keys = 15
# top pool = 29
# lowest error = 8.38491503
# counter = 6
# children pool = 27
# merged pool = 37
# # of keys = 15
# top pool = 30
# lowest error = 8.38491503
# counter = 7
# children pool = 30
# merged pool = 35
# # of keys = 15
# top pool = 28
# lowest error = 8.38491503
# counter = 8
# children pool = 28
# merged pool = 33
# # of keys = 15
# top pool = 32
# lowest error = 8.38491503
# counter = 9
# children pool = 32
# merged pool = 37
# # of keys = 15
# top pool = 30
# lowest error = 8.38491503
# counter = 10
# children pool = 28
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 8.38491503
# counter = 11
# children pool = 32
# merged pool = 39
# # of keys = 15
# top pool = 31
# lowest error = 8.38491503
# counter = 12
# children pool = 29
# merged pool = 39
# # of keys = 15
# top pool = 32
# lowest error = 7.48284749
# counter = 13
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 34
# lowest error = 7.48284749
# counter = 14
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 7.48284749
# counter = 15
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 7.48284749
# counter = 16
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 30
# lowest error = 7.48284749
# counter = 17
# children pool = 29
# merged pool = 37
# # of keys = 15
# top pool = 30
# lowest error = 7.48284749
# counter = 18
# children pool = 29
# merged pool = 36
# # of keys = 15
# top pool = 28
# lowest error = 7.48284749
# counter = 19
# children pool = 28
# merged pool = 35
# # of keys = 15
# top pool = 31
# lowest error = 7.48284749
# counter = 20
# children pool = 29
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 7.48284749
# counter = 21
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 7.48284749
# counter = 22
# children pool = 34
# merged pool = 42
# # of keys = 20
# top pool = 30
# lowest error = 7.48284749
# counter = 23
# children pool = 29
# merged pool = 41
# # of keys = 20
# top pool = 32
# lowest error = 7.48284749
# counter = 24
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 33
# lowest error = 7.48284749
# counter = 25
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 7.48284749
# counter = 26
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 7.48284749
# counter = 27
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 7.48284749
# counter = 28
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 7.48284749
# counter = 29
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 7.48284749
# counter = 30
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 32
# lowest error = 7.48284749
# counter = 31
# children pool = 31
# merged pool = 39
# # of keys = 15
# top pool = 32
# lowest error = 7.48284749
# counter = 32
# children pool = 31
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 7.48284749
# counter = 33
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 7.48284749
# counter = 34
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 7.43773959
# counter = 35
# children pool = 34
# merged pool = 49
# # of keys = 20
# top pool = 33
# lowest error = 7.43773959
# counter = 36
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 7.43773959
# counter = 37
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 7.43773959
# counter = 38
# children pool = 33
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 7.43773959
# counter = 39
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 32
# lowest error = 7.43773959
# counter = 40
# children pool = 32
# merged pool = 47
# # of keys = 20
# top pool = 32
# lowest error = 7.43244515
# counter = 41
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 7.43244515
# counter = 42
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 7.43244515
# counter = 43
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 7.43244515
# counter = 44
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 7.43244515
# counter = 45
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 46
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 47
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 48
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 32
# lowest error = 7.22898052
# counter = 49
# children pool = 30
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 50
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 51
# children pool = 34
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 52
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 53
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 7.22898052
# counter = 54
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 7.22898052
# counter = 55
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 56
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 32
# lowest error = 7.22898052
# counter = 57
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 7.22898052
# counter = 58
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 59
# children pool = 31
# merged pool = 38
# # of keys = 15
# top pool = 30
# lowest error = 7.22898052
# counter = 60
# children pool = 30
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 61
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 62
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 63
# children pool = 34
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 64
# children pool = 32
# merged pool = 50
# # of keys = 25
# top pool = 35
# lowest error = 7.22898052
# counter = 65
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 66
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 7.22898052
# counter = 67
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 7.22898052
# counter = 68
# children pool = 32
# merged pool = 50
# # of keys = 25
# top pool = 36
# lowest error = 7.22898052
# counter = 69
# children pool = 36
# merged pool = 49
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 70
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 71
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 32
# lowest error = 5.2075386
# counter = 72
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 73
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 5.2075386
# counter = 74
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 75
# children pool = 34
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 76
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 77
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 78
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 79
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 80
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 81
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 82
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 83
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 84
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 85
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 86
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 87
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 88
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 89
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 32
# lowest error = 5.2075386
# counter = 90
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 91
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 92
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 93
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 94
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 95
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 96
# children pool = 33
# merged pool = 48
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 97
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 98
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 99
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 100
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 101
# children pool = 36
# merged pool = 52
# # of keys = 25
# top pool = 35
# lowest error = 5.2075386
# counter = 102
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 103
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 104
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 105
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 106
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 107
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 108
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 109
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 110
# children pool = 34
# merged pool = 51
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 111
# children pool = 36
# merged pool = 52
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 112
# children pool = 36
# merged pool = 49
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 113
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 114
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 115
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 29
# lowest error = 5.2075386
# counter = 116
# children pool = 28
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 117
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 118
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 119
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 120
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 36
# lowest error = 5.2075386
# counter = 121
# children pool = 36
# merged pool = 51
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 122
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 123
# children pool = 36
# merged pool = 51
# # of keys = 25
# top pool = 37
# lowest error = 5.2075386
# counter = 124
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 125
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 126
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 5.2075386
# counter = 127
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 128
# children pool = 34
# merged pool = 51
# # of keys = 25
# top pool = 35
# lowest error = 5.2075386
# counter = 129
# children pool = 32
# merged pool = 49
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 130
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 131
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 132
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 133
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 5.2075386
# counter = 134
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 5.2075386
# counter = 135
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.86078044
# counter = 136
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.86078044
# counter = 137
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.86078044
# counter = 138
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.86078044
# counter = 139
# children pool = 33
# merged pool = 52
# # of keys = 25
# top pool = 37
# lowest error = 4.86078044
# counter = 140
# children pool = 33
# merged pool = 49
# # of keys = 20
# top pool = 32
# lowest error = 4.86078044
# counter = 141
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.86078044
# counter = 142
# children pool = 30
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.86078044
# counter = 143
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 4.86078044
# counter = 144
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.86078044
# counter = 145
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.74962981
# counter = 146
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 4.74962981
# counter = 147
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.74962981
# counter = 148
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 149
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 150
# children pool = 34
# merged pool = 51
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 151
# children pool = 35
# merged pool = 55
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 152
# children pool = 35
# merged pool = 54
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 153
# children pool = 36
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 154
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 155
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 156
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 157
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 158
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 159
# children pool = 33
# merged pool = 49
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 160
# children pool = 33
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 161
# children pool = 35
# merged pool = 50
# # of keys = 25
# top pool = 35
# lowest error = 4.67106674
# counter = 162
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 163
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 164
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 165
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 166
# children pool = 30
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 167
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 168
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 169
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 170
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 171
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 172
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 173
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 174
# children pool = 33
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 175
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 176
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 177
# children pool = 34
# merged pool = 53
# # of keys = 25
# top pool = 36
# lowest error = 4.67106674
# counter = 178
# children pool = 36
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 179
# children pool = 33
# merged pool = 49
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 180
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 181
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 182
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 183
# children pool = 31
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 184
# children pool = 34
# merged pool = 51
# # of keys = 25
# top pool = 35
# lowest error = 4.67106674
# counter = 185
# children pool = 34
# merged pool = 49
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 186
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 187
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 188
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 189
# children pool = 30
# merged pool = 46
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 190
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 191
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 30
# lowest error = 4.67106674
# counter = 192
# children pool = 29
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 193
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 194
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 195
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 196
# children pool = 34
# merged pool = 51
# # of keys = 25
# top pool = 34
# lowest error = 4.67106674
# counter = 197
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 198
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 199
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 200
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 201
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 202
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 203
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 204
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 205
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 206
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 207
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 208
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 209
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 210
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 211
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 31
# lowest error = 4.67106674
# counter = 212
# children pool = 30
# merged pool = 40
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 213
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 214
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 215
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 216
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 217
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 218
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 219
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 220
# children pool = 33
# merged pool = 49
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 221
# children pool = 31
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 222
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 223
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 224
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 225
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 226
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 227
# children pool = 31
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 228
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 35
# lowest error = 4.67106674
# counter = 229
# children pool = 30
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 230
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 231
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 232
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 233
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 234
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 235
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 236
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 237
# children pool = 31
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 238
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 239
# children pool = 33
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 240
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 241
# children pool = 33
# merged pool = 50
# # of keys = 25
# top pool = 36
# lowest error = 4.67106674
# counter = 242
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 31
# lowest error = 4.67106674
# counter = 243
# children pool = 30
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.67106674
# counter = 244
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 245
# children pool = 33
# merged pool = 50
# # of keys = 25
# top pool = 36
# lowest error = 4.67106674
# counter = 246
# children pool = 36
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 247
# children pool = 35
# merged pool = 50
# # of keys = 25
# top pool = 35
# lowest error = 4.67106674
# counter = 248
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 249
# children pool = 34
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.67106674
# counter = 250
# children pool = 35
# merged pool = 55
# # of keys = 25
# top pool = 36
# lowest error = 4.67106674
# counter = 251
# children pool = 34
# merged pool = 49
# # of keys = 20
# top pool = 33
# lowest error = 4.67106674
# counter = 252
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 253
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 254
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 255
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 32
# lowest error = 4.67106674
# counter = 256
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.67106674
# counter = 257
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 258
# children pool = 34
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 259
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 260
# children pool = 31
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 261
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 262
# children pool = 30
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 263
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 264
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 265
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 266
# children pool = 31
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 267
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 268
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 269
# children pool = 34
# merged pool = 40
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 270
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.66828653
# counter = 271
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 272
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 273
# children pool = 34
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 274
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 275
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 276
# children pool = 31
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 277
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 278
# children pool = 30
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 279
# children pool = 34
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 280
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 281
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 282
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 283
# children pool = 33
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 284
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 285
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 286
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 287
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 288
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 289
# children pool = 33
# merged pool = 48
# # of keys = 20
# top pool = 32
# lowest error = 4.66828653
# counter = 290
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 291
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 292
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 293
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 294
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 295
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 296
# children pool = 32
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.66828653
# counter = 297
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66828653
# counter = 298
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 30
# lowest error = 4.66828653
# counter = 299
# children pool = 30
# merged pool = 38
# # of keys = 15
# top pool = 30
# lowest error = 4.66828653
# counter = 300
# children pool = 27
# merged pool = 35
# # of keys = 15
# top pool = 32
# lowest error = 4.66828653
# counter = 301
# children pool = 31
# merged pool = 36
# # of keys = 15
# top pool = 32
# lowest error = 4.66828653
# counter = 302
# children pool = 32
# merged pool = 36
# # of keys = 15
# top pool = 29
# lowest error = 4.66828653
# counter = 303
# children pool = 27
# merged pool = 38
# # of keys = 15
# top pool = 31
# lowest error = 4.66828653
# counter = 304
# children pool = 29
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66828653
# counter = 305
# children pool = 33
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 306
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 307
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 308
# children pool = 29
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 309
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 310
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 311
# children pool = 31
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 312
# children pool = 29
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 313
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 314
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 315
# children pool = 31
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 316
# children pool = 30
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 317
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 318
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 319
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 320
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 321
# children pool = 33
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 322
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 323
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 324
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 325
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 326
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 327
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 328
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 329
# children pool = 32
# merged pool = 39
# # of keys = 15
# top pool = 30
# lowest error = 4.66435889
# counter = 330
# children pool = 29
# merged pool = 39
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 331
# children pool = 30
# merged pool = 37
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 332
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 333
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 334
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 335
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 31
# lowest error = 4.66435889
# counter = 336
# children pool = 30
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 337
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 338
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 339
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 340
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 341
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 342
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 343
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 344
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 345
# children pool = 32
# merged pool = 45
# # of keys = 20
# top pool = 30
# lowest error = 4.66435889
# counter = 346
# children pool = 29
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 347
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 348
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 349
# children pool = 31
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 350
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 351
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 352
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 353
# children pool = 31
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 354
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 355
# children pool = 29
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 356
# children pool = 33
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 357
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 358
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 359
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 360
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 361
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 362
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 363
# children pool = 31
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 364
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 365
# children pool = 34
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 366
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 367
# children pool = 30
# merged pool = 39
# # of keys = 15
# top pool = 29
# lowest error = 4.66435889
# counter = 368
# children pool = 27
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 369
# children pool = 31
# merged pool = 37
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 370
# children pool = 30
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 371
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 372
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 373
# children pool = 30
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 374
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 375
# children pool = 33
# merged pool = 50
# # of keys = 25
# top pool = 37
# lowest error = 4.66435889
# counter = 376
# children pool = 35
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 377
# children pool = 34
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 378
# children pool = 34
# merged pool = 39
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 379
# children pool = 30
# merged pool = 39
# <ipython-input-545-f83ed01f3e61>:32: RuntimeWarning: invalid value encountered in sin
#   bh[i] = np.sin(bh[2*i])
# # of keys = 15
# top pool = 28
# lowest error = 4.66435889
# counter = 380
# children pool = 28
# merged pool = 35
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 381
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 382
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 383
# children pool = 33
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 384
# children pool = 34
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 385
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 386
# children pool = 30
# merged pool = 45
# # of keys = 20
# top pool = 31
# lowest error = 4.66435889
# counter = 387
# children pool = 30
# merged pool = 38
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 388
# children pool = 30
# merged pool = 39
# # of keys = 15
# top pool = 30
# lowest error = 4.66435889
# counter = 389
# children pool = 30
# merged pool = 36
# # of keys = 15
# top pool = 29
# lowest error = 4.66435889
# counter = 390
# children pool = 27
# merged pool = 36
# # of keys = 15
# top pool = 29
# lowest error = 4.66435889
# counter = 391
# children pool = 27
# merged pool = 36
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 392
# children pool = 30
# merged pool = 37
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 393
# children pool = 31
# merged pool = 40
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 394
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 395
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 396
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 397
# children pool = 34
# merged pool = 46
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 398
# children pool = 29
# merged pool = 41
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 399
# children pool = 33
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 400
# children pool = 34
# merged pool = 47
# # of keys = 20
# top pool = 31
# lowest error = 4.66435889
# counter = 401
# children pool = 30
# merged pool = 37
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 402
# children pool = 29
# merged pool = 39
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 403
# children pool = 29
# merged pool = 37
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 404
# children pool = 29
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 405
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 406
# children pool = 33
# merged pool = 49
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 407
# children pool = 33
# merged pool = 41
# # of keys = 20
# top pool = 31
# lowest error = 4.66435889
# counter = 408
# children pool = 29
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 409
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 410
# children pool = 34
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 411
# children pool = 30
# merged pool = 41
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 412
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 413
# children pool = 33
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 414
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 415
# children pool = 34
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 416
# children pool = 34
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 417
# children pool = 32
# merged pool = 40
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 418
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 419
# children pool = 31
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 420
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 421
# children pool = 31
# merged pool = 42
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 422
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 423
# children pool = 30
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 424
# children pool = 34
# merged pool = 49
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 425
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 426
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 427
# children pool = 34
# merged pool = 38
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 428
# children pool = 28
# merged pool = 38
# # of keys = 15
# top pool = 31
# lowest error = 4.66435889
# counter = 429
# children pool = 28
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 430
# children pool = 30
# merged pool = 37
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 431
# children pool = 32
# merged pool = 38
# # of keys = 15
# top pool = 32
# lowest error = 4.66435889
# counter = 432
# children pool = 30
# merged pool = 38
# # of keys = 15
# top pool = 29
# lowest error = 4.66435889
# counter = 433
# children pool = 28
# merged pool = 40
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 434
# children pool = 33
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 435
# children pool = 34
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 436
# children pool = 32
# merged pool = 42
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 437
# children pool = 33
# merged pool = 48
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 438
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 439
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 440
# children pool = 32
# merged pool = 46
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 441
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 442
# children pool = 30
# merged pool = 43
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 443
# children pool = 31
# merged pool = 43
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 444
# children pool = 32
# merged pool = 43
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 445
# children pool = 31
# merged pool = 44
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 446
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 447
# children pool = 32
# merged pool = 44
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 448
# children pool = 34
# merged pool = 41
# # of keys = 20
# top pool = 33
# lowest error = 4.66435889
# counter = 449
# children pool = 32
# merged pool = 41
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 450
# children pool = 33
# merged pool = 45
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 451
# children pool = 31
# merged pool = 45
# # of keys = 20
# top pool = 32
# lowest error = 4.66435889
# counter = 452
# children pool = 31
# merged pool = 45
# # of keys = 20
# top pool = 34
# lowest error = 4.66435889
# counter = 453
# children pool = 33
# merged pool = 40
# # of keys = 20
# top pool = 35
# lowest error = 4.66435889
# counter = 454
# children pool = 32
# merged pool = 48
# # of keys = 20
# top pool = 31
# lowest error = 4.66435889
# counter = 455
# children pool = 29
# merged pool = 39
# ...
#   2.9488800231550236,
#   3.0127598090683514,
#   3.087977292772959,
#   3.1404397917822755,
#   3.450754258132054,
#   3.476111633835165,
#   3.572123410785382,
#   3.5796630958845572,
#   3.656591792444983,
#   3.6684666814405453,
#   3.738310931268896,
#   3.771080015433002,
#   3.7865628779610443,
#   3.793403563757033,
#   3.8074434961490615,
#   3.8290384031203812,
#   3.908855023879946,
#   3.9138824888510535,
#   4.11185960382482,
#   4.124639035483488,
#   4.144137946068915,
#   4.179507779928646,
#   4.282446616175166,
#   4.3037321262907895,
#   4.555295681845303,
#   4.564004205645121,
#   4.576038076453002,
#   4.592371899658935,
#   4.633465100964892,
#   4.660771438434233,
#   4.71164192333448,
#   4.855127590514284,
#   4.92790522648097,
#   4.94280375934269,
#   5.0414368147864215,
#   5.1203057952413165,
#   5.165965488673757,
#   5.19895840506915,
#   5.203044788491416,
#   5.203589001032734,
#   5.2667359657304935,
#   5.274346976228895,
#   5.314974179351669,
#   5.337566097438023,
#   5.342849873539743,
#   5.50213864223644,
#   5.515188644594472,
#   5.551705411799963,
#   5.596081382190677,
#   5.621416080774777,
#   5.718049241075279,
#   5.730770853610473,
#   5.80936553049165,
#   5.823665826467012,
#   5.838633861971436,
#   5.862811464239373,
#   5.863789369958232,
#   5.9013976636331815,
#   5.902551634199032,
#   5.904530304957081,
#   5.909143085775671,
#   5.9156233169684524,
#   5.920365623486706,
#   5.930654154835348,
#   5.936645596719341,
#   5.938362743804483,
#   5.940983859324608,
#   5.966105335127455,
#   5.986610697370164,
#   5.992576659789755,
#   6.008693092011956,
#   6.00943442575131,
#   6.0100480755294825,
#   6.010046679184018,
#   6.010035541394574,
#   6.005342401662022,
#   6.002610702114284,
#   5.9872778311736115,
#   5.974470057603829,
#   5.973259801587452,
#   5.972735168719546,
#   5.928289494001941,
#   5.906588201644915,
#   5.874250117853981,
#   5.8727502277285915,
#   5.839583301267847,
#   5.83026098190286,
#   5.785185070159182,
#   5.713754645159043,
#   5.6719877976893205,
#   5.655278642386785,
#   5.641183428415193,
#   5.637142923090063,
#   5.590501538967418,
#   5.515914640892435,
#   5.456367795320364,
#   5.418508435588238,
#   5.339036127890843,
#   5.336528561748688,
#   5.328413905294196,
#   5.309987189395159,
#   5.3060956394259176,
#   5.285990604201391,
#   5.283641608903277,
#   5.194118302865087,
#   5.021305616864303,
#   4.922094936425931,
#   4.863296430768934,
#   4.823893171205752,
#   4.81901808971214,
#   4.790673571609941,
#   4.73736375876283,
#   4.736603639644482,
#   4.719179202634088,
#   4.640456046376067,
#   4.63881560881739,
#   4.626827429712586,
#   4.51660166264965,
#   4.51660166264965,
#   4.462842030018638,
#   4.451576719963585,
#   4.398994417920197,
#   4.3861800496139765,
#   4.327052403115012,
#   4.311566912203194,
#   4.295387691263475,
#   4.282078061418284,
#   4.272866901945796,
#   4.256503605967348,
#   4.255643748645038,
#   4.25441795240726,
#   4.210005589492997,
#   4.194406245069638,
#   4.18355384377683,
#   4.180183481143178,
#   4.170679163382816,
#   4.14226688727207,
#   4.139019378422926,
#   4.135646245745802,
#   4.115326216337669,
#   4.10302977705822,
#   4.100471683176646,
#   4.08848386010608,
#   4.08518992568904,
#   4.0766189879719565,
#   4.069343862169463,
#   4.0658352280363435,
#   4.052343025939758,
#   4.0517886954924265,
#   4.044853351604939,
#   4.042187291645385,
#   4.0394159487937955,
#   4.038753261559772,
#   4.033878687786303,
#   4.031739402668162,
#   4.030082376744568,
#   4.029902366910411,
#   4.031347960675836,
#   4.043327892908152,
#   4.0656093921508205,
#   4.074286994118035,
#   4.079829103452643,
#   4.092448225284883,
#   4.097746183320201,
#   4.113309011740061,
#   4.135572823211536,
#   4.139980671786961,
#   4.1485302875348635,
#   4.149534667494785,
#   4.153844124106909,
#   4.19053051523551,
#   4.203464313847908,
#   4.209386618015708,
#   4.222080395373395,
#   4.2322923376363075,
#   4.238159319661203,
#   4.2448362969493925,
#   4.248580273464526,
#   4.254079318145368,
#   4.267328420350246,
#   4.27299610295289,
#   4.310448385123241,
#   4.319888822938509,
#   4.326678011605367,
#   4.3440541645690685,
#   4.388160631343878,
#   4.4244630541514365,
#   4.44682048030241,
#   4.4722525138084155,
#   4.530779317404612,
#   4.586025207283621,
#   4.599124726907652,
#   4.6244014033689,
#   4.7680547108833045,
#   4.772109113193594,
#   4.792156211456145,
#   4.811108335205704,
#   4.816284875069126,
#   4.881750662109061,
#   4.888490505840172,
#   4.909129401144586,
#   4.941613251539092,
#   4.943429767289205,
#   4.991642163415072,
#   5.025362659088065,
#   5.055045995993809,
#   5.0759747458815045,
#   5.096714930779433,
#   5.110165919314824,
#   5.12512900229346,
#   5.154413344997995,
#   5.155220667275023,
#   5.185031831163976,
#   5.197074925969332,
#   5.207341222470428,
#   5.212923444451296,
#   5.215898845346566,
#   5.220580040182942,
#   5.2243216068875,
#   5.252431819670519,
#   5.253697593468774,
#   5.263203260046092,
#   5.264419286658462,
#   5.265922343288979,
#   5.268043852566999,
#   5.269684179765006,
#   5.277659303935682,
#   5.278173364944985,
#   5.278718182279693,
#   5.279454607093324,
#   5.279479485595417,
#   5.279647920953987,
#   5.278864799617596,
#   5.277594816325452,
#   5.270791414258254,
#   5.26135384279966,
#   5.251835946962625,
#   5.2498002825658,
#   5.221780059357139,
#   5.196004313858034,
#   5.19374526776361,
#   5.19024450275805,
#   5.181402920853642,
#   5.176614125615812,
#   5.168941032906041,
#   5.135254271645472,
#   5.131739778297209,
#   5.101134914175672,
#   5.08576438579394,
#   5.084558791358946,
#   5.07097237528113,
#   5.070796429005554,
#   5.013307624923348,
#   4.934686281965305,
#   4.930245864954533,
#   4.898702525338164,
#   4.8885132956308,
#   4.88237660027043,
#   4.859030783462698,
#   4.857705229974387,
#   4.836840640475415,
#   4.7681454205248475,
#   4.75105086212874,
#   4.716217950561774,
#   4.714407229092916,
#   4.682430838184054,
#   4.647280834426058,
#   4.612136375976247,
#   4.607097698517579,
#   4.6007843396977375,
#   4.600844516947625,
#   4.600897325882261,
#   4.60143908867044,
#   4.615711094561665,
#   4.61697175038365,
#   4.619266229230367,
#   4.636575722314084,
#   4.663262131455917,
#   4.66515103102021,
#   4.66766563149485,
#   4.685078076555973,
#   4.7023680092735685,
#   4.70489557377831,
#   4.766520761059835,
#   4.8189535874828096,
#   4.833055972854687,
#   4.845992645099495,
#   4.856723964034515,
#   4.857628965911628,
#   4.883956033980393,
#   4.893725344598257,
#   4.913607148397957,
#   4.948109823995795,
#   4.9822266616351785,
#   5.013907079712299,
#   5.043860764855657,
#   5.134474362906181,
#   5.1545193388279795,
#   5.172662382847266,
#   5.218896506690458,
#   5.227829912918511,
#   5.245161812331486,
#   5.425917490548443,
#   5.450437978203377,
#   5.480775687365284,
#   5.502371952025506,
#   5.525882642069608,
#   5.5533543549151805,
#   5.605231490060261,
#   5.839871336394992,
#   5.886413663213861,
#   6.015038944831497,
#   6.185064120092374,
#   6.188504309688708,
#   6.308828784130825,
#   6.386541599540689,
#   6.431428311519465,
#   6.553765129867846,
#   6.592590302208441,
#   6.617335746592985,
#   6.650166689855354,
#   6.661495027493469,
#   6.791110544518931,
#   6.795533995121893,
#   6.86384065553537,
#   6.931574538362689,
#   6.956773458549113,
#   7.031685240275611,
#   7.063960594629309,
#   7.072863993532373,
#   7.122194234964363,
#   7.193344233866057,
#   7.221473730637303,
#   7.276912744812309,
#   7.419249442994369,
#   7.43681385291543,
#   7.441201339195636,
#   7.517727889076671,
#   7.527892373045235,
#   7.560134414451403,
#   7.592270066473287,
#   7.641155404209254,
#   7.65869913797682,
#   7.665491506255234,
#   7.674419898550659,
#   7.7726248040141765,
#   7.836017102987209,
#   7.8721375561958915,
#   7.9289584836570715,
#   7.939564696511877,
#   8.0453442315504,
#   8.19991056665282,
#   8.52853557423759,
#   8.55552803573675,
#   8.621407242107992,
#   8.65399543691791,
#   8.684403438636473,
#   8.691399294600657,
#   8.768231914410672,
#   8.802358171926528,
#   8.814006885935768,
#   8.84345496062092,
#   8.911232764794967,
#   8.95045750411011,
#   9.004498867647015,
#   9.027442233950637,
#   9.086930165886072,
#   9.094750716086526,
#   9.10296021902364,
#   9.103458775144954,
#   9.110389193853987,
#   9.149120008275032,
#   9.153624352581701,
#   9.17372670691249,
#   9.254275242610138,
#   9.28413027572299,
#   9.30169090714855,
#   9.306762309212441,
#   9.318646864441277,
#   9.323719948987625,
#   9.32905865224934,
#   9.332062452630923,
#   9.350168025882871,
#   9.352149250620474,
#   9.357207050143394,
#   9.352350663080916,
#   9.351965341773331,
#   9.348106053180409,
#   9.343675544736161,
#   9.342255448915294,
#   9.333531742436925,
#   9.281385742196363,
#   9.258760261659187,
#   9.237899328021918,
#   9.219188214883935,
#   9.204297726846843,
#   9.195582095306706,
#   9.159219720731516,
#   9.134503626725841,
#   9.131433000977676,
#   9.056767504129322,
#   8.973901766171174,
#   8.952696871428632,
#   8.912641708002667,
#   8.808450898639522,
#   8.791013916969028,
#   8.756869255480545,
#   8.599824836883993,
#   8.588966398702658,
#   8.493194555619532,
#   8.40907407149883,
#   8.378442150300957,
#   8.327013032006171,
#   8.245968068851115,
#   8.155620037628648,
#   8.050034673447861,
#   7.974780530462408,
#   7.9505558180839495,
#   7.871883315070546,
#   7.77910193188837,
#   7.757964512696748,
#   7.749625779399709,
#   7.634013087304223,
#   7.619408367802892,
#   7.570995466636652,
#   7.5074984605913935,
#   7.477332471046893,
#   7.442222906670008,
#   7.4052570901117445,
#   7.397717429939987,
#   7.357643862808862,
#   7.351175118762965,
#   7.296425058652568,
#   7.284953060233104,
#   7.233634130017339,
#   7.198694041674996,
#   7.142099269870406,
#   6.9989861755978255,
#   6.974039052138582,
#   6.943053769007949,
#   6.908405545215853,
#   6.885120584075462,
#   6.858296317017995,
#   6.849695163935363,
#   6.7986416861785655,
#   6.790625486301165,
#   6.764251086472161,
#   6.72200963757711,
#   6.71558046332271,
#   6.685051883678858,
#   6.684365670423977,
#   6.68203951512225,
#   6.639533079071942,
#   6.619676084658769,
#   6.617207970425731,
#   6.603093577225995,
#   6.574884846378372,
#   6.564574058275419,
#   6.536577957866726,
#   6.515915048964489,
#   6.511796846064041,
#   6.4818421662915355,
#   6.480362588686696,
#   6.473349667761358,
#   6.470442283417847,
#   6.4695667849044645,
#   6.460541809558948,
#   6.457767368783029,
#   6.453731518351974,
#   6.452629206288674,
#   6.446809588281741,
#   6.444259137627973,
#   6.442926284888065,
#   6.4447670739800715,
#   6.449326436589626,
#   6.4530726122993824,
#   6.453291316465559,
#   6.454709252825545,
#   6.470826320391061,
#   6.4916599565805395,
#   6.49264237330833,
#   6.496783287063366,
#   6.504941860965911,
#   6.5198171492702315,
#   6.525143781743573,
#   6.525363099571629,
#   6.538526634849083,
#   6.545833009796979,
#   6.576634821933136,
#   6.5782644501047685,
#   6.597400561589458,
#   6.601934133741601,
#   6.604367352376421,
#   6.646983294207306,
#   6.661082812423257,
#   6.663834679589187,
#   6.712257943276862,
#   6.780794318561833,
#   6.792952521832174,
#   6.848752517096417,
#   6.855319056789206,
#   6.876113796535764,
#   6.920964676278845,
#   6.924427532711963,
#   6.929976962759551,
#   6.939992166805219,
#   6.9429193270571155,
#   6.979076398272584,
#   7.043736410989162,
#   7.06930548398272,
#   7.072289204174439,
#   7.081239666744627,
#   7.110481502873029,
#   7.120543997006903,
#   7.141760668930637,
#   7.185347434731307,
#   7.208213580288874,
#   7.221107293914602,
#   7.244657758371337,
#   7.277723580686907,
#   7.280826325873876,
#   7.326998059206077,
#   7.351461411666209,
#   7.373464350078567,
#   7.380167239102105,
#   7.411387823899108,
#   7.441569822985121,
#   7.4908088160644954,
#   7.503646317652727,
#   7.50594465516555,
#   7.543564840472644,
#   7.546532531046074,
#   7.573368515567712,
#   7.585390183321907,
#   7.58764308016937,
#   7.604875613147124,
#   7.606397224844003,
#   7.619469965674922,
#   7.637324505896618,
#   7.645046210858347,
#   7.647889187852442,
#   7.657687572845453,
#   7.658896367757789,
#   7.667632899379834,
#   7.6768922418529675,
#   7.69252004795189,
#   7.695773931679245,
#   7.699586806295751,
#   7.700634051329036,
#   7.704276622760376,
#   7.709872978369827,
#   7.711425205016091,
#   7.713749825674993,
#   7.718985575604583,
#   7.726063670960446,
#   7.72827869359554,
#   7.734184037095742,
#   7.740006711465963,
#   7.7411861975250345,
#   7.7458979057161494,
#   7.758849281666731,
#   7.764267460896886,
#   7.767458996721823,
#   7.771966000369313,
#   7.776284811411294,
#   7.776518369348979,
#   7.782616294475428,
#   7.782697041278676,
#   7.776613654104482,
#   7.773423933669631,
#   7.757703972793936,
#   7.756963143197938,
#   7.75604620866876,
#   7.7461001002776335,
#   7.745911069361208,
#   7.742516349710148,
#   7.733644070400728,
#   7.726003408562532,
#   7.72364725101088,
#   7.717603259143276,
#   7.702881887286882,
#   7.6989881635438095,
#   7.690088234833745,
#   7.688501658077142,
#   7.682595454838477,
#   7.678526583350382,
#   7.675550239464216,
#   7.661491122574336,
#   7.654799642031151,
#   7.63475997324279,
#   7.6347013224671425,
#   7.633509389888319,
#   7.6328210112436246,
#   7.612878138251828,
#   7.61250778317161,
#   7.611108128598316,
#   7.609299944491383,
#   7.608807882155853,
#   7.608630047840921,
#   7.608210097839194,
#   7.6077490009710225,
#   7.6094681973130704,
#   7.610043406418161,
#   7.610970249102108,
#   7.6113155476479974,
#   7.612557221198179,
#   7.613687584638765,
#   7.620780065893195,
#   7.621521211457749,
#   7.625020807400537,
#   7.6300571341850105,
#   7.632666133689586,
#   7.633479559357511,
#   7.64149434051047,
#   7.644132380432742,
#   7.652284614665179,
#   7.67663502009788,
#   7.681085714077398,
#   7.729509140305918,
#   7.733242095022929,
#   7.740412372241886,
#   7.751334997510064,
#   7.758434860641301,
#   7.790744519737157,
#   7.800420398561047,
#   7.817965141231294,
#   7.837028439789451,
#   7.852618535325134,
#   7.867507649427727,
#   7.888320110651816,
#   7.93135147252643,
#   7.9384228812550415,
#   7.946233300613276,
#   8.04838341718781,
#   8.216814248679285,
#   8.279505814750141,
#   8.31664595495071,
#   8.334982715704014,
#   8.46937830493424,
#   8.604502209365892,
#   8.611402227889506,
#   8.612554390889045,
#   8.645649028972574,
#   8.647697319938612,
#   8.661792780941528,
#   8.771782822884317,
#   8.773939768230793,
#   8.808376350996976,
#   8.824972693505456,
#   8.852745294569278,
#   8.911672446324697,
#   8.92301035975112,
#   8.984598924924455,
#   9.081800464461931,
#   9.120710649607904,
#   9.217868032939037,
#   9.263710317949842,
#   9.598258740958453,
#   9.624550066889926,
#   9.676636993604587,
#   9.743145461691848,
#   9.886779152477164,
#   10.232653367963069,
#   10.316420225530354,
#   10.326256601680864,
#   10.464330225430869,
#   10.471405037000885,
#   10.491444713174282,
#   10.56718492032683,
#   10.641545413504701,
#   10.713688989286894,
#   10.770012210722312,
#   10.83690963344551,
#   10.921045329678634,
#   11.010532040403024,
#   11.071674444044037,
#   11.195386493664595,
#   11.2581764795592,
#   11.286952632309374,
#   11.294213603695198,
#   11.29457639295873,
#   11.337568786330223,
#   11.34906784551719,
#   11.365908338611876,
#   11.541909546343001,
#   11.554241673652577,
#   11.632379004969264,
#   11.646395769861618,
#   11.990804885406245,
#   11.99138558305754,
#   12.168827410841597,
#   12.35864297475747,
#   12.376659489078023,
#   12.383162472561592,
#   12.39261405113488,
#   12.3998471443583,
#   12.431630996435555,
#   12.507434447915355,
#   12.513411020179248,
#   12.529225531938057,
#   12.612043133206827,
#   12.646632056724174,
#   12.668417712791733,
#   12.671180767331435,
#   12.725668334660902,
#   12.725844287315919,
#   12.736442769543627,
#   12.75495410566807,
#   12.78743545600656,
#   12.78755355915326,
#   12.787394228452413,
#   12.78297735613591,
#   12.78195572536814,
#   12.781864758251011,
#   12.781773254734606,
#   12.775096431600375,
#   12.743935140741566,
#   12.72855480852284,
#   12.726768694487141,
#   12.70714142231485,
#   12.67530721719064,
#   12.663951490455545,
#   12.663352217654058,
#   12.641135531443286,
#   12.640746458688206,
#   12.634588073111988,
#   12.627096497395723,
#   12.62328819433649,
#   12.611896794073953,
#   12.604201954663221,
#   12.580966824800743,
#   12.485926220691512,
#   12.483031688650804,
#   12.471883590500914,
#   12.461492969108875,
#   12.45133279791367,
#   12.414501120275144,
#   12.399908102337305,
#   12.36645636639204,
#   12.266504994222387,
#   12.263533388577663,
#   12.191869241343698,
#   12.112829994765114,
#   12.104972800245397,
#   12.095549838421796,
#   12.067250138903145,
#   12.055812366499849,
#   12.047975813088495,
#   11.985817266914832,
#   11.911364416909391,
#   11.848388464493262,
#   11.764503903672718,
#   11.510818150753542,
#   11.447504220157722,
#   11.30813995478491,
#   11.27868706147855,
#   11.223059815918518,
#   11.108424078090678]]

# %%
res_rrhc = random_restart_hill_climber(num_eval=num_evaluation, x_s=x_s, y_s=y_s, depth=8, num_tries=10)
# Out:
# 0.0 % complete
# 20.0 % complete
# 40.0 % complete
# 60.0 % complete
# 80.0 % complete
# <ipython-input-545-f83ed01f3e61>:28: RuntimeWarning: divide by zero encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]

# %%
res_rmhc = random_mutation_hill_climber(num=num_evaluation, x_s=x_s, y_s=y_s, depth=8)
# Out:
# 0.0 % complete
# 20.0 % complete
# 40.0 % complete
# 60.0 % complete
# 80.0 % complete

# %%
res_rs = random_search(num=num_evaluation, x_s=x_s, y_s=y_s, depth=8)
# Out:
# 0.0 % complete
# <ipython-input-11-f83ed01f3e61>:28: RuntimeWarning: divide by zero encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]
# <ipython-input-11-f83ed01f3e61>:28: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] / bh[2*i+1]
# <ipython-input-11-f83ed01f3e61>:36: RuntimeWarning: invalid value encountered in cos
#   bh[i] = np.cos(bh[2*i])
# <ipython-input-11-f83ed01f3e61>:24: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] * bh[2*i+1]
# <ipython-input-11-f83ed01f3e61>:32: RuntimeWarning: invalid value encountered in sin
#   bh[i] = np.sin(bh[2*i])
# 2.0 % complete
# 4.0 % complete
# 6.0 % complete
# 8.0 % complete
# <ipython-input-11-f83ed01f3e61>:20: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] - bh[2*i+1]
# 10.0 % complete
# 12.0 % complete
# 14.000000000000002 % complete
# 16.0 % complete
# <ipython-input-11-f83ed01f3e61>:16: RuntimeWarning: invalid value encountered in double_scalars
#   bh[i] = bh[2*i] + bh[2*i+1]
# 18.0 % complete
# 20.0 % complete
# 22.0 % complete
# 24.0 % complete
# 26.0 % complete
# 28.000000000000004 % complete
# 30.0 % complete
# 32.0 % complete
# 34.0 % complete
# 36.0 % complete
# 38.0 % complete
# 40.0 % complete
# 42.0 % complete
# 44.0 % complete
# 46.0 % complete
# 48.0 % complete
# 50.0 % complete
# 52.0 % complete
# 54.0 % complete
# 56.00000000000001 % complete
# 57.99999999999999 % complete
# 60.0 % complete
# 62.0 % complete
# 64.0 % complete
# 66.0 % complete
# 68.0 % complete
# 70.0 % complete
# 72.0 % complete
# 74.0 % complete
# 76.0 % complete
# 78.0 % complete
# 80.0 % complete
# 82.0 % complete
# 84.0 % complete
# 86.0 % complete
# 88.0 % complete
# 90.0 % complete
# 92.0 % complete
# 94.0 % complete
# 96.0 % complete
# 98.0 % complete

# %%
print(len(res_ea[0]))
print(len(res_ea[1]))
print(len(res_ea[2]))
print(len(res_ea[3]))

# %%
plt.figure(figsize=(10,10))
plt.scatter(res_rs[0], res_rs[1], color='purple', label='random search')
plt.plot(res_rs[0], res_rs[1], color='purple')

# plt.scatter(res_rmhc[0], res_rmhc[1], color='orange', label='random mutation hill climber')
# plt.plot(res_rmhc[0], res_rmhc[1], color='orange')

# plt.scatter(res_rrhc[0], res_rrhc[1], color='blue', label='random restart hill climber')
# plt.plot(res_rrhc[0], res_rrhc[1], color='blue')

# plt.scatter(res_ea[0], res_ea[1], color='green', label='EA')
# plt.plot(res_ea[0], res_ea[1], color='green')

plt.scatter(res_ea_div_mut[0], res_ea_div_mut[1], color='red', label='EA_mut_div')
plt.plot(res_ea_div_mut[0], res_ea_div_mut[1], color='red')

plt.legend()

plt.ylim(0, 100)
plt.xscale('log')
plt.ylabel("Fitness")
plt.xlabel("Evaluation");

# %%
res_rrhc[2]

# %%
plt.figure(figsize=(10,10))
plt.plot(x_s, y_s, label="acutal data");
# plt.plot(x_s, res_rs[3], label="random search");
# plt.plot(x_s, res_rrhc[3], label="random restart HC");
# plt.plot(x_s, res_rmhc[3], label="random mutation HC");
# plt.plot(x_s, res_ea[3], label="EA_div");
# plt.plot(x_s, res_ea_div_mut[3], label="EA_div_mut");
plt.legend()

# %%
def save_data(result, title):
    today = datetime.now()
    d = today.strftime("%Y-%m-%d-%H-%M")
    path = "/Users/dxx0511a/Desktop/Columbia/MECS_4510_EA/hw2/output/" 
    
    df_plot = pd.DataFrame(data={'evaluation': result[0], 'mse': result[1]})
    df_graph = pd.DataFrame(data={"y_cal": result[3]})
    
    with open(f"{path}{d}_{title}_e{num_evaluation}_final_equation.txt",'w') as e:
            for ele in result[2]:
                e.write(str(ele))
                e.write('\n')
                

    df_plot.to_csv(f"{path}{d}_{title}_e{num_evaluation}_plot.csv", index=False)
    df_graph.to_csv(f"{path}{d}_{title}_e{num_evaluation}_graph.csv", index=False)

# %%
# save_data(res_rs,title="rs")
# save_data(res_rmhc,title="rmhc")
# save_data(res_rrhc,title="rrhc")
save_data(res_ea,title="ea_div")

# %%
arr = [1,2,3,4]
def dummy(arr):
    for i in range(len(arr)):
        arr.remove(arr[i])
    return arr
dummy(arr)

# %%
a =[1,2,3,4,5,6]
b = ['a','b']
i = 0
while i < len(a):
    for ele in b:
        print (ele)
    i += 1
